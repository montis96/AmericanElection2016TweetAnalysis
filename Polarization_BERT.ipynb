# %% [markdown]
# # Import libraries

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install tqdm

# !pip install emoji
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (4.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (0.1.95)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (1.2.0)

# %%
from transformers import BertTokenizer, BertModel
from transformers import pipeline

from google.colab import drive

import pandas as pd
import os
import string
import numpy as np

## Preprocessing
import emoji
import re
import html
import nltk
import regex

#Cosine
from scipy.spatial.distance import cosine

# %% [markdown]
# # Load dataset

# %%
drive.mount('/content/drive', force_remount = True)
root_dir = '/content/drive/MyDrive/ProgettoAI/dataset/'

trump = pd.read_csv(root_dir+'tweet_with_entities_trump.csv', index_col=0  ).rename(columns={'tweet' : 'text'})
clinton = pd.read_csv(root_dir+'tweet_with_entities_clinton.csv', index_col=0  ).rename(columns={'tweet' : 'text'})
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocessing

# %%
START_OF_LINE = r"^"
OPTIONAL = "?"
ANYTHING = "."
ZERO_OR_MORE = "*"
ONE_OR_MORE = "+"

SPACE = "\s"
SPACES = SPACE + ONE_OR_MORE
NOT_SPACE = "[^\s]" + ONE_OR_MORE
EVERYTHING_OR_NOTHING = ANYTHING + ZERO_OR_MORE

ERASE = ""
FORWARD_SLASH = "\/"
NEWLINES = r"[\r\n]"

RE_TWEET = START_OF_LINE + "RT" + SPACES

HYPERLINKS = ("http" + "s" + OPTIONAL + ":" + FORWARD_SLASH + FORWARD_SLASH
              + NOT_SPACE + NEWLINES + ZERO_OR_MORE)

HASH = "#"
TAG = "@"

def cleaning_up(tweets):
    print("CLEANING...")
    clean =[]
    
    for tweet in tweets['text']:

        tweet = html.unescape(html.unescape(tweet)) #caratteri html
        tweet = re.sub(RE_TWEET, ERASE, tweet)  #re:
        tweet = re.sub(HYPERLINKS, ERASE, tweet) #url
        tweet = re.sub(HASH, ERASE, tweet) #hash simbolo
        tweet = re.sub(TAG, ERASE, tweet)
        #tweet = re.sub("@[^\s]+",ERASE,tweet) #tag username
        tweet = re.sub('<.*?>', ERASE, tweet) #tag html
        tweet = emoji.demojize(tweet) #traduzione delle emoji
        tweet = re.sub(r":", ' ', tweet) #serve per le emoji
        tweet = re.sub(r'\d+', '', tweet) #number
        tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    
        clean.append(tweet)
      
    print("---CLEANED---")

    return clean

def get_wordnet_pos(tag):
    if tag[1].startswith('J'):
        return wordnet.ADJ
    elif tag[1].startswith('S'):
        return wordnet.ADJ_SAT
    elif tag[1].startswith('V'):
        return wordnet.VERB
    elif tag[1].startswith('N'):
        return wordnet.NOUN
    elif tag[1].startswith('R'):
        return wordnet.ADV
    else:
        return ''

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

def tweet_tokenize(tweets):
    
    print("TOKENIZATION...")
    all_tokens=[]
    tokens =[] 
    tokenizer = word_tokenize

    for tweet in tweets:
        temp=[]
        all_tokens = tokenizer(tweet)
        lemmatizer = WordNetLemmatizer()
        stop_words = stopwords.words('english')
        for token in all_tokens:
                token = token.lower()
                if not (
                    not token.isalpha()
                    or token in stop_words 
                    or token in string.punctuation
                    or (token.isalpha() and len(token) < 2)):
                        tagged = nltk.pos_tag([token])
                        parsed = get_wordnet_pos(tagged[0])
                        #if parsed != '':
                         #   token = lemmatizer.lemmatize(token, parsed)
                        temp.append(token)
        tokens.append(temp) 

    print("---TOKENIZED---")

    return tokens

def get_word_frequencies(corpus):
  frequencies = Counter()
  for sentence in corpus:
    for word in sentence:
      frequencies[word] += 1
  freq = frequencies.most_common()
  return freq
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
trump_cleaned = cleaning_up(trump)

clinton_cleaned = cleaning_up(clinton)
# Out:
# CLEANING...
# ---CLEANED---
# CLEANING...
# ---CLEANED---

# %% [markdown]
# # BERT Embedding

# %% [markdown]
# ## Loading Pre-Trained BERT

# %%
import torch
from transformers import BertTokenizer, BertModel

# OPTIONAL: if you want to have more information on what's happening, activate the logger as follows
import logging
#logging.basicConfig(level=logging.INFO)

import matplotlib.pyplot as plt
% matplotlib inline

# Load pre-trained model tokenizer (vocabulary)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load pre-trained model (weights)
model = BertModel.from_pretrained('bert-base-uncased',
                                  output_hidden_states = True, # Whether the model returns all hidden-states.
                                  )

# Put the model in "evaluation" mode, meaning feed-forward operation.
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def sentenceEmb (model, tokenizer, text, concatenation = False):
  marked_text = "[CLS] " + text + " [SEP]"
  # Tokenize our sentence with the BERT tokenizer.
  tokenized_text = tokenizer.tokenize(marked_text)

  # Map the token strings to their vocabulary indeces.
  indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)

  segments_ids = []
  # Mark each of the 22 tokens as belonging to sentence "1".
  segments_ids = [1] * len(tokenized_text)

  #Extracting embedding
  tokens_tensor = torch.tensor([indexed_tokens])
  segments_tensors = torch.tensor([segments_ids])

  #extract hidden layers
  with torch.no_grad():

    outputs = model(tokens_tensor, segments_tensors)

    # Evaluating the model will return a different number of objects based on 
    # how it's  configured in the `from_pretrained` call earlier. In this case, 
    # becase we set `output_hidden_states = True`, the third item will be the 
    # hidden states from all layers. See the documentation for more details:
    # https://huggingface.co/transformers/model_doc/bert.html#bertmodel
    hidden_states = outputs[2]

  # Concatenate the tensors for all layers. We use `stack` here to
  # create a new dimension in the tensor.
  token_embeddings = torch.stack(hidden_states, dim=0)

  # Remove dimension 1, the "batches".
  token_embeddings = torch.squeeze(token_embeddings, dim=1)

  # Swap dimensions 0 and 1.
  token_embeddings = token_embeddings.permute(1,0,2)

  if concatenation:
    # Stores the token vectors, with shape [22 x 3,072]
    token_vecs = []

    # `token_embeddings` is a [22 x 12 x 768] tensor.

    # For each token in the sentence...
    for token in token_embeddings:
        # `token` is a [12 x 768] tensor

        # Concatenate the vectors (that is, append them together) from the last 
        # four layers.
        # Each layer vector is 768 values, so `cat_vec` is length 3,072.
        cat_vec = torch.cat((token[-1], token[-2], token[-3], token[-4]), dim=0)
        # Use `cat_vec` to represent `token`.
        token_vecs.append(cat_vec)
  else:
    # Stores the token vectors, with shape [22 x 768]
    token_vecs = []

    # `token_embeddings` is a [22 x 12 x 768] tensor.

    # For each token in the sentence...
    for token in token_embeddings:

        # `token` is a [12 x 768] tensor

        # Sum the vectors from the last four layers.
        sum_vec = torch.sum(token[-4:], dim=0)
        
        # Use `sum_vec` to represent `token`.
        token_vecs.append(sum_vec)

  return tokenized_text, token_vecs

# %%
tt, tv = sentenceEmb(model, tokenizer, 'hillaryclinton')

dt, tv = sentenceEmb(model, tokenizer, 'Make maerica great again')

# %%
tt[1:-1].flat()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-d507d79ab69d> in <module>()
# ----> 1 tt[1:-1].flat()
#
# AttributeError: 'list' object has no attribute 'flat'

# %%
#Trump tokenizer and embedding

tokens_trump = []
embeddings_trump = []

for text in trump_cleaned:
  tokenized_text, token_vecs = sentenceEmb(model, tokenizer, text)

  tokens_trump.append(tokenized_text)
  sentence_embedding = []
  for v in token_vecs:
    sentence_embedding.append(v.numpy())
  embeddings_trump.append(sentence_embedding)


#Clinton tokenizer and embedding
tokens_clinton = []
embeddings_clinton = []

for text in clinton_cleaned:
  tokenized_text, token_vecs = sentenceEmb(model, tokenizer, text)

  tokens_clinton.append(tokenized_text)
  sentence_embedding = []
  for v in token_vecs:
    sentence_embedding.append(v.numpy())
  embeddings_clinton.append(sentence_embedding)

# %%
sentence_embedding[0]
# Out:
# array([-7.01385915e-01,  1.37577176e+00,  2.08979845e+00, -2.17674121e-01,
#        -8.38985145e-01,  2.56600767e-01,  4.17990148e-01,  8.82463217e-01,
#        -1.60964370e+00, -2.23472714e+00, -1.04536319e+00,  1.51058626e+00,
#         6.28996253e-01,  9.41049308e-02,  7.70534873e-01,  3.79816800e-01,
#        -1.56935477e+00,  3.56678581e+00,  1.80336165e+00, -2.76877689e+00,
#        -1.70014596e+00, -9.62671936e-02, -8.95076022e-02,  3.84426475e-01,
#         1.42107630e+00, -1.19696617e+00, -7.86139667e-01,  1.22600913e+00,
#        -1.31915554e-01,  1.39288642e-02,  6.60530925e-01,  1.37799606e-01,
#         6.77503586e-01,  1.34147239e+00,  8.92655134e-01, -1.02731675e-01,
#         2.67512053e-01, -3.33304666e-02,  8.58516634e-01, -1.35721505e+00,
#        -6.66298568e-01, -5.48627853e-01,  1.51756191e+00, -2.19638586e+00,
#         4.98484075e-02, -4.97163594e-01, -1.56651649e+01,  3.02153373e+00,
#         1.13799417e+00, -2.19182515e+00,  1.99454618e+00, -1.11700392e+00,
#         1.42123342e+00,  3.14793301e+00,  1.86287463e+00,  2.86228627e-01,
#         3.26365054e-01, -8.15809488e-01,  5.69787323e-01,  3.54044199e-01,
#         2.49262378e-01, -1.22147858e+00, -2.17978048e+00, -7.38264322e-01,
#        -8.85381460e-01,  8.63770306e-01,  2.21286988e+00,  1.11792958e+00,
#        -2.14331174e+00,  1.75658667e+00,  4.88213837e-01,  1.88067126e+00,
#         1.54053247e+00,  1.07248712e+00, -5.41497208e-02, -3.88374776e-01,
#         4.18266565e-01,  3.85780990e-01, -1.67237237e-01, -1.78508222e+00,
#        -5.90144247e-02, -1.22418523e-01,  4.21162605e-01,  8.16862226e-01,
#        -1.73242688e-01,  7.70230293e-01,  1.66935849e+00, -3.34384322e+00,
#         2.91741848e-01,  1.82401466e+00, -1.84989858e+00,  7.70408928e-01,
#         9.67978597e-01,  6.48596466e-01,  2.70073962e+00, -1.70150685e+00,
#        -2.71524358e+00, -1.65606129e+00,  1.64485550e+00, -3.82884562e-01,
#        -2.75683928e+00,  1.62635517e+00, -7.29923666e-01, -2.62290502e+00,
#         5.13923168e-01,  6.90722764e-02,  1.23110175e+00,  9.90261853e-01,
#         1.00881207e+00, -3.57022524e+00,  3.79474193e-01, -4.99990493e-01,
#        -9.13160503e-01, -1.36139381e+00, -7.43637025e-01,  3.93835306e-01,
#         1.80640841e+00, -1.15123466e-02,  3.74952227e-01, -7.88416326e-01,
#        -4.62821126e-01,  2.23912692e+00, -3.02675903e-01, -1.64814591e+00,
#         2.41959190e+00,  2.18494344e+00, -9.85656142e-01, -2.05145001e+00,
#         2.67285675e-01,  2.13483143e+00, -9.18344110e-02,  3.64157081e-01,
#        -2.37561345e+00, -6.81986928e-01,  8.01733732e-01,  1.17325358e-01,
#         1.58733439e+00,  1.11512339e+00, -1.15899873e+00, -1.83745101e-01,
#        -2.97744274e+00, -1.15444434e+00, -8.35321236e+00,  1.97334337e+00,
#         6.98169827e-01, -9.04215634e-01, -2.95998478e+00,  2.01512384e+00,
#        -2.06414628e+00,  2.25484824e+00, -6.90377295e-01,  1.93448171e-01,
#        -1.34655130e+00,  2.74554706e+00, -6.15649760e-01,  1.49113965e+00,
#         4.38224912e-01, -3.49854541e+00,  1.79373229e+00,  3.83680391e+00,
#        -8.71611178e-01,  2.60165185e-01,  1.30486131e-01, -1.34660661e+00,
#         3.80662084e-01, -1.81149328e+00,  1.03154078e-01,  1.42203414e+00,
#         5.91217160e-01, -7.16625214e-01, -8.33840072e-01, -7.44403064e-01,
#        -2.27912396e-01, -1.53927076e+00,  3.30079722e+00, -2.57354200e-01,
#         2.12430716e-01, -1.47607893e-01, -3.82386684e-01,  1.23100591e+00,
#         6.64533913e-01, -6.12197936e-01,  3.04487735e-01,  2.53350496e+00,
#        -2.98632413e-01, -3.84865373e-01,  1.96833563e+00,  9.73442197e-01,
#         7.27710724e-01,  8.45114291e-01,  2.19251156e-01,  9.49131012e-01,
#         2.72239351e+00,  6.68085754e-01,  1.26355529e+00,  3.74555975e-01,
#        -1.00980651e+00, -1.47571242e+00,  3.27657914e+00, -3.82914484e-01,
#         1.11239028e+00,  3.76050711e-01,  1.07803929e+00, -1.60064864e+00,
#        -1.78598893e+00,  8.60929489e+00, -5.22056818e-01, -2.03295875e+00,
#        -5.44734359e-01,  2.40992522e+00, -1.67931688e+00,  6.19267762e-01,
#        -2.92781502e-01, -1.24745950e-01, -1.46925211e+00, -9.05891359e-01,
#         1.11228228e+00,  1.30577117e-01,  1.13902700e+00,  1.09012842e+00,
#        -5.36086440e-01,  1.52668869e+00,  1.02566218e+00,  7.13397115e-02,
#         7.94924378e-01,  1.92250621e+00,  5.92537522e-01, -8.68315697e-01,
#        -1.24075794e+00, -4.75007057e+00, -6.89254940e-01, -2.99774706e-01,
#        -2.97664261e+00,  1.53135204e+00,  1.21228816e-02,  8.94441009e-01,
#         2.79267579e-01, -2.39264131e-01,  1.61713505e+00,  4.67719674e-01,
#        -3.58702540e-01, -6.92384958e-01,  1.84987795e+00,  1.38131225e+00,
#        -1.38188040e+00,  2.06284356e+00,  5.80878913e-01,  7.03320920e-01,
#         8.13315034e-01, -3.58590543e-01,  2.66067314e+00, -2.74772620e+00,
#         1.20443475e+00, -6.32600367e-01, -3.11316490e-01,  6.29872024e-01,
#        -3.42704415e-01, -1.15910006e+00, -3.04537725e+00, -2.13224888e+00,
#         4.63607550e-01,  1.77902192e-01, -8.16909432e-01, -5.33586025e-01,
#        -1.10616617e-01, -2.70251811e-01, -2.04188538e+00, -3.11189508e+00,
#         1.10305142e+00, -7.63998568e-01, -1.77774632e+00,  1.34645569e+00,
#        -1.61174953e+00, -4.97794199e+00,  1.42549455e+00,  5.15289903e-01,
#         1.91632426e+00,  2.82616735e+00,  1.87721407e+00, -3.98517728e-01,
#         1.95178032e+00, -1.56800163e+00, -4.19952869e-01,  1.01729727e+00,
#         6.26078963e-01, -1.67799795e+00, -4.19656634e-02, -1.46440148e+00,
#         4.14678425e-01,  1.62591040e-03,  2.55566621e+00,  7.30801284e-01,
#         1.09662223e+00,  1.39630169e-01,  2.00122976e+00, -1.85516667e+00,
#         1.21314692e+00,  7.94025362e-01, -1.60355639e+00, -6.62896395e-01,
#        -1.47033370e+00,  2.75387287e+00, -3.18168712e+00, -4.23801392e-01,
#         7.46569991e-01, -7.10678577e-01, -1.51432562e+00, -3.09134603e+00,
#        -4.35565796e+01, -9.14538503e-01,  3.55220139e-01, -2.58800864e+00,
#        -2.61683390e-02, -1.10100582e-01,  2.46931124e+00,  2.87442297e-01,
#        -5.82460523e-01,  8.65565598e-01,  3.70715380e-01,  9.94882464e-01,
#        -2.38485026e+00, -2.22496057e+00,  1.61008030e-01, -3.35274279e-01,
#         5.57827592e-01, -1.27328634e+00, -2.75186747e-01, -1.10590780e+00,
#        -4.08063442e-01, -1.61327779e-01,  4.53616172e-01,  2.53314853e-01,
#        -1.62281466e+00, -4.75549191e-01, -1.75044775e+00, -4.63929251e-02,
#        -1.46087551e+00,  1.43032610e+00, -1.97125936e+00,  7.86561489e-01,
#        -9.66503739e-01, -3.07204103e+00, -2.20677781e+00, -1.52040040e+00,
#         6.07972503e-01,  5.81536472e-01,  3.22915196e+00,  1.11656475e+00,
#        -1.03722548e+00,  1.61651087e+00, -3.79518807e-01,  1.55253887e+00,
#         1.85122979e+00,  6.72243953e-01, -9.34565485e-01,  7.52118528e-01,
#        -1.54687154e+00,  1.91037512e+00,  5.36006629e-01, -1.03579926e+00,
#         5.48603249e+00, -1.87506115e+00,  1.43088579e+00,  1.07514285e-01,
#         1.47060394e+00,  1.43428016e+00,  7.42967546e-01, -1.63310432e+00,
#         1.42066956e+00,  5.40579855e-02,  2.81921172e+00,  1.72406770e-02,
#        -2.43116379e-01,  8.85612294e-02,  1.34898746e+00, -7.77081192e-01,
#        -9.72631097e-01, -7.15486884e-01, -1.82903945e+00,  1.07972756e-01,
#         1.55333176e-01, -1.19446030e+01, -9.00506318e-01,  1.24756145e+00,
#        -3.40555859e+00,  8.71499300e-01,  2.77832913e+00, -2.36572623e-01,
#        -3.62554121e+00,  6.24285415e-02,  2.30417705e+00,  5.15600443e-01,
#        -4.45521688e+00,  6.76387548e-01, -1.08857262e+00, -5.61640896e-02,
#        -5.52684605e-01,  2.05909324e+00, -2.09067523e-01,  3.98861051e-01,
#        -1.47232056e+00, -2.09579766e-01,  8.25734496e-01,  1.29612064e+00,
#         2.86212468e+00, -3.09406567e+00,  3.27522047e-02,  8.73152435e-01,
#         9.34980392e-01,  4.93874550e-02,  3.12687337e-01, -1.55075336e+00,
#        -7.12216973e-01, -1.24856067e+00,  9.89392221e-01,  6.91202343e-01,
#        -1.97835732e+00,  5.10143995e-01, -4.49662864e-01,  1.71440601e+00,
#        -2.81404734e+00,  9.96662259e-01,  3.15481186e+00,  6.40973032e-01,
#        -2.07401109e+00, -4.64438766e-01, -4.69845563e-01, -6.93164587e-01,
#        -7.45164335e-01,  1.38754487e+00,  8.04162920e-01, -3.10828328e-01,
#        -6.88036978e-02, -7.21128434e-02, -2.17848015e+00, -3.13583875e+00,
#        -1.71295905e+00,  9.04586077e-01,  3.33442497e+00, -1.75211108e+00,
#        -5.42208612e-01, -2.73232841e+00, -1.67034483e+00, -8.56987357e-01,
#        -6.89819574e-01,  8.39439571e-01,  3.76380622e-01,  3.68270367e-01,
#         3.28440809e+00, -3.75150412e-01, -1.71667099e+00,  3.41782713e+00,
#        -1.15986317e-01,  1.70024484e-01,  3.21897417e-01, -3.53998095e-01,
#         5.98801613e-01,  2.54200697e+00, -8.08925688e-01, -2.58651948e+00,
#         1.90117586e+00,  5.77282786e-01,  8.68999958e-01, -3.17154586e-01,
#        -1.89260900e-01, -2.09513068e+00, -1.59421861e+00,  4.34593171e-01,
#         5.67521811e-01, -1.47198009e+00, -8.73011208e+00,  1.71129954e+00,
#         1.34398806e+00, -1.67322481e+00,  1.04596090e+00, -1.95773733e+00,
#        -2.92807519e-01, -2.25900531e-01, -1.61115956e+00,  1.55838323e+00,
#        -1.32821035e+00,  7.63903141e-01, -1.60533607e+00, -5.03158212e-01,
#         1.91925669e+00,  3.61215711e-01,  9.81408656e-02,  1.19159222e+00,
#         1.51370764e+00,  1.34715116e+00,  1.33857775e+00,  2.68957043e+00,
#        -2.15979028e+00, -1.17078483e+00,  5.74980140e-01,  3.49738538e-01,
#         7.63660431e-01,  1.37718189e+00, -3.12120175e+00,  6.77837670e-01,
#         2.15964150e+00, -1.74655092e+00, -8.34588468e-01,  1.06576037e+00,
#         1.30368733e+00,  2.59839392e+00,  1.25294602e+00,  7.49231756e-01,
#        -1.15639317e+00,  4.76853773e-02, -1.10358477e+00,  2.35017276e+00,
#         9.64289188e-01, -1.86394781e-01,  1.57346046e+00, -1.62427163e+00,
#         1.22597903e-01,  1.82229549e-01,  7.64006376e-01, -4.47477102e-01,
#         1.39504373e+00, -6.37764871e-01,  7.43528426e-01, -4.39751482e+00,
#        -7.28699565e-02,  1.32886207e+00, -1.42259347e+00, -6.56583905e-01,
#        -7.56916285e-01, -7.63463616e-01,  1.59217525e+00,  9.77003038e-01,
#         6.30119681e-01,  1.63978863e+00, -1.48309481e+00, -2.68529582e+00,
#         1.98348373e-01,  1.22241390e+00, -1.95728636e+00,  1.50846851e+00,
#         2.08228874e+00,  1.42194748e+00,  1.00738740e+00, -1.23664129e+00,
#        -1.14464676e+00,  2.53441000e+00,  5.99524021e-01,  1.66152334e+00,
#         7.25689411e-01, -2.19725037e+00,  6.11708820e-01, -3.25489974e+00,
#        -2.79248142e+00,  1.23051155e+00, -4.65264022e-01,  1.83158979e-01,
#         6.27651513e-01,  1.48961914e+00,  6.67655468e-01, -7.29584575e-01,
#        -7.22110331e-01, -1.49707139e+00,  1.46420956e+00, -2.09386885e-01,
#         2.21678957e-01, -3.01548451e-01,  1.28450048e+00, -1.09019756e+00,
#        -1.70406926e+00,  6.14049613e-01, -3.83794427e-01,  2.87901133e-01,
#         1.28307629e+00,  3.99661690e-01,  1.29024851e+00,  1.08002889e+00,
#         1.51126969e+00,  1.49578965e+00, -3.21311742e-01,  1.60883081e+00,
#         6.17361307e-01,  3.84807372e+00, -1.89985847e+00, -5.31368911e-01,
#        -7.13401794e-01,  2.03893757e+00, -5.40518522e-01,  5.01444519e-01,
#         3.90375638e+00, -5.27177036e-01, -1.77350307e+00,  1.59604132e+00,
#         7.64456332e-01,  3.04806709e-01,  1.20507073e+00, -3.81106615e-01,
#         1.45449676e-02,  1.07539153e+00,  1.29105783e+00,  9.04098094e-01,
#        -2.82462788e+00, -2.35519484e-01,  9.15346622e-01,  2.11051059e+00,
#        -2.88652390e-01, -1.27718675e+00, -3.74446064e-01, -5.95926285e-01,
#        -2.57095766e+00,  7.51739562e-01,  4.05644000e-01, -1.37561262e+00,
#        -2.08916396e-01, -1.25278282e+00, -7.07407534e-01, -9.72160995e-01,
#        -1.57650638e+00, -6.63414955e-01, -4.86497492e-01,  3.14539254e-01,
#        -3.09450895e-01,  1.56821489e+00, -4.96382952e-01,  3.06835592e-01,
#         4.10577714e-01, -1.28448880e+00, -2.74657071e-01,  1.08353138e+00,
#        -1.48193765e+00, -1.30873978e+00,  4.15537310e+00,  3.76699746e-01,
#         5.67032576e-01,  9.49470639e-01,  4.49459314e-01, -9.58834648e-01,
#         1.85589993e+00, -3.93430412e-01, -4.05865371e-01, -1.51974511e+00,
#        -1.88909322e-01, -5.18678486e-01, -4.66017693e-01, -2.03028822e+00,
#        -2.91299760e-01, -1.03870857e+00, -2.25968337e+00,  3.33379221e+00,
#        -1.37030649e+00, -5.58227301e-01, -1.08697546e+00, -3.98947299e-01,
#         2.50258350e+00,  8.64852667e-02, -6.10593021e-01,  2.27216661e-01,
#        -8.59235227e-02, -1.39712894e+00,  1.84674919e-01,  2.80909920e+00,
#        -7.04803944e-01, -7.69035816e-01,  1.77365589e+00, -1.33653116e+00,
#         2.16226220e+00, -2.21817040e+00,  7.81156778e-01, -6.20359612e+00,
#        -6.09520257e-01,  1.20902908e+00,  2.34045163e-01,  8.21233869e-01,
#         1.45629442e+00, -2.34940577e+00, -4.98524576e-01,  1.28779161e+00,
#         3.08501422e-01, -6.63143277e-01,  1.19216941e-01, -1.20365012e+00,
#        -1.88429639e-01,  1.86208141e+00, -1.80099630e+00, -1.17828333e+00,
#        -1.51921737e+00, -1.35765836e-01,  2.70978153e-01,  6.53059483e-01,
#         7.52313361e-02, -1.94251418e+00, -6.90030336e-01, -3.58761579e-01,
#        -3.16453159e-01,  6.61522210e-01, -1.30471408e-01,  1.91264957e-01,
#        -1.37668288e+00,  4.22892421e-01, -2.49463618e-01,  2.72971034e-01,
#         8.87625933e-01, -4.98294711e-01,  3.24930966e-01, -5.25177360e-01,
#        -6.73123956e-01, -9.65779424e-01, -9.16658878e-01, -2.58778214e-01,
#         2.43652686e-01,  9.86112714e-01,  7.45268106e-01,  4.83995408e-01,
#         4.99857903e-01,  2.04548264e+00, -1.76101446e+00,  1.02198076e+00,
#        -3.11952263e-01,  7.28605926e-01,  6.91553354e-01, -7.16727853e-01,
#        -3.23512927e-02,  2.56836796e+00, -9.92296815e-01,  1.80077434e+00,
#         1.91780603e+00,  5.56068838e-01, -3.87270570e-01,  5.93685627e-01,
#        -2.49347165e-01, -1.37626040e+00,  3.52471173e-01,  3.65172774e-01,
#         3.03777486e-01,  1.22530830e+00, -2.08173847e+00, -7.34564662e-02,
#         9.55700934e-01, -1.54484674e-01, -3.72388512e-01,  1.84068799e+00,
#         5.47200561e-01, -4.10890132e-02, -6.18111193e-01,  1.19189352e-01,
#         5.71592245e-03,  1.14972842e+00,  2.76933503e+00,  1.49376154e-01,
#        -1.82539916e+00,  7.07556546e-01,  3.65197599e-01,  1.26100886e+00,
#        -1.14539843e+01, -1.58097744e+00,  1.37290514e+00,  2.13996053e+00,
#        -1.79429412e+00, -1.89553821e+00, -1.83741963e+00, -1.50504160e+00,
#        -1.63412797e+00,  2.24505872e-01,  1.51426065e+00, -1.21052718e+00,
#        -9.72315520e-02, -8.05576086e-01, -8.21225405e-01,  1.11509764e+00],
#       dtype=float32)

# %%
def word_vec(tokens, embeddings, word):  # return the embedding of a word
  word_vecs = []
  i_sentence = 0
  for sentence in tokens:
    i_token = 0
    for t in sentence:
      if t == word:
        word_vecs.append(embeddings[i_sentence][i_token])

      i_token = i_token + 1
    i_sentence = i_sentence + 1

  return word_vecs

import numpy as np
def sum_vec(word_vecs):  
  vec_sum = np.zeros(len(word_vecs[0]))
  for v in word_vecs:
    vec_sum = vec_sum + v
  
  return vec_sum

# %%
def polarity(tokens, embeddings, topic, A, B):
  positive_score = 0
  negative_score = 0
  
  #Get list of vector
  t_list = []
  for t in topic:
    t_vec =  sum_vec(word_vec(tokens, embeddings, t))
    t_list.append(t_vec)

  a_list = []
  for a in A:
    a_vec =  sum_vec(word_vec(tokens, embeddings, a))
    a_list.append(a_vec)
      
  b_list = []
  for b in B:
    b_vec =  sum_vec(word_vec(tokens, embeddings, b))
    b_list.append(b_vec)

 # Polarity:
  for t in t_list:
    positive_temp = 0
    for a in a_list:
      positive_temp = positive_temp + ( 1 - cosine(t, a))
    positive_temp = positive_temp/len(a_list)
    

    negative_temp = 0
    for b in b_list:
      negative_temp = negative_temp + ( 1 - cosine(t, b))
    negative_temp = negative_temp/len(b_list)


    positive_score = positive_score + positive_temp
    negative_score = negative_score + negative_temp

  polarity = positive_score - negative_score
  print('Positive score: ', positive_score)
  print('Negative score: ', negative_score)
  print('Difference score: ', polarity)

  return polarity

# %% [markdown]
# # Donald Trump

# %%
topic = ['hillary', 'clinton', 'democratic', 'dem']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong']

polarity(tokens_trump, embeddings_trump, topic, positive, negative)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-d18152f6fefa> in <module>()
#       3 negative = ['bad', 'badly', 'negative', 'false', 'wrong']
#       4
# ----> 5 polarity(tokens_trump, embeddings_trump, topic, positive, negative)
#
# <ipython-input-12-d3c4d9e74616> in polarity(tokens, embeddings, topic, A, B)
#       6   t_list = []
#       7   for t in topic:
# ----> 8     t_vec =  sum_vec(word_vec(tokens, embeddings, t))
#       9     t_list.append(t_vec)
#      10
#
# <ipython-input-11-661b89cbb5ce> in sum_vec(word_vecs)
#      17   vec_sum = np.zeros(len(word_vecs[0]))
#      18   for v in word_vecs:
# ---> 19     vec_sum = vec_sum + v
#      20
#      21   return vec_sum
#
# TypeError: unsupported operand type(s) for +: 'numpy.ndarray' and 'Tensor'

# %%
topic = ['trump', 'republican']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong']

polarity(tokens_trump, embeddings_trump, topic, positive, negative)

# %%
topic = [ 'hillary', 'clinton', 'dem', 'democratic', 'obama', 'barack']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong']

polarity(tokens_trump, embeddings_trump, topic, positive, negative)

# %%
good_vecs = word_vec(tokens_trump, embeddings_trump, 'good')
good = sum_vec(good_vecs)

hillary_vecs = word_vec(tokens_trump, embeddings_trump, 'hillary')
hillary = sum_vec(hillary_vecs)

trump_vecs = word_vec(tokens_trump, embeddings_trump, 'trump')
trump = sum_vec(trump_vecs)

from scipy.spatial.distance import cosine
1 - cosine(good, trump)

# %% [markdown]
# # Hillary Clinton

# %%
topic = ['hillary', 'clinton', 'democratic', 'dem']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong']

polarity(tokens_clinton, embeddings_clinton, topic, positive, negative)
# Out:
# Positive score:  1.8833880798195333
# Negative score:  1.757009232265519
# Difference score:  0.12637884755401418
# 0.12637884755401418

# %%
good_vecs = word_vec(tokens_clinton, embeddings_clinton, 'good')
good = sum_vec(good_vecs)

hillary_vecs = word_vec(tokens_clinton, embeddings_clinton, 'hillary')
hillary = sum_vec(hillary_vecs)

trump_vecs = word_vec(tokens_clinton, embeddings_clinton, 'trump')
trump = sum_vec(trump_vecs)

from scipy.spatial.distance import cosine
1 - cosine(good, trump)
# Out:
# 0.5290500518669969

# %% [markdown]
# # Save embedding

# %% [markdown]
# Trump

# %%
import csv

with open("tokens_trump_bert.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(tokens_trump)

# %%
 np.save('embedding_trump_bert.npy',embeddings_trump)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Clinton

# %%
with open("tokens_clinton_bert.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(tokens_clinton)

# %%
 #np.save('embedding_clinton_bert.npy',embeddings_clinton)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
tokens_trump
# Out:
# [['[CLS]',
#   'join',
#   'me',
#   'for',
#   'a',
#   'pm',
#   'rally',
#   '##ing',
#   'tomorrow',
#   'at',
#   'the',
#   'mid',
#   '##ame',
#   '##rica',
#   '##cent',
#   '##er',
#   'in',
#   'rails',
#   '##west',
#   '##rail',
#   '##ro',
#   '##ad',
#   '##mus',
#   '##eum',
#   'tickets',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'once',
#   'again',
#   'we',
#   'will',
#   'have',
#   'a',
#   'government',
#   'of',
#   'by',
#   'and',
#   'for',
#   'the',
#   'people',
#   'join',
#   'the',
#   'movement',
#   'the',
#   '##be',
#   '##ach',
#   '##boys',
#   '##to',
#   '##day',
#   '[SEP]'],
#  ['[CLS]',
#   'on',
#   'national',
#   'voter',
#   '##re',
#   '##gist',
#   '##ration',
#   '##day',
#   'make',
#   'sure',
#   'your',
#   '##e',
#   'registered',
#   'to',
#   'vote',
#   'so',
#   'we',
#   'can',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   '##s',
#   'campaign',
#   'continues',
#   'to',
#   'make',
#   'false',
#   'united',
#   '##sta',
#   '##tes',
#   '##house',
#   '##com',
#   '##mit',
#   '##tee',
#   '##ont',
#   '##he',
#   '##ju',
#   '##dic',
#   '##iary',
#   'about',
#   'foundation',
#   'corporation',
#   '[SEP]'],
#  ['[CLS]',
#   'cn',
#   '##bc',
#   'time',
#   '##ma',
#   '##ga',
#   '##zine',
#   'online',
#   'polls',
#   'say',
#   'donald',
#   '##trum',
#   '##p',
#   'won',
#   'the',
#   'first',
#   'united',
#   '##sta',
#   '##tes',
#   '##pres',
#   '##ide',
#   '##ntial',
#   '##de',
#   '##bate',
#   '##s',
#   'via',
#   'wash',
#   '##time',
#   '##s',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   'afternoon',
#   'in',
#   'little',
#   '##havan',
#   '##a',
#   'with',
#   'race',
#   '##and',
#   '##eth',
#   '##nic',
#   '##ity',
#   '##int',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '##cens',
#   '##us',
#   'community',
#   'leaders',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'support',
#   'im',
#   '##with',
#   '##you',
#   '[SEP]'],
#  ['[CLS]',
#   'in',
#   'the',
#   'last',
#   'hr',
#   '##sal',
#   '##bu',
#   '##m',
#   'we',
#   'have',
#   'raised',
#   'over',
#   'm',
#   'from',
#   'online',
#   'donations',
#   'and',
#   'national',
#   'call',
#   'day',
#   'and',
#   'we',
#   '’',
#   're',
#   'still',
#   'going',
#   'thank',
#   'you',
#   'united',
#   '##sta',
#   '##tes',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'well',
#   'now',
#   'they',
#   '##re',
#   'saying',
#   'that',
#   'i',
#   'not',
#   'only',
#   'won',
#   'the',
#   'nbc',
#   'presidential',
#   'forum',
#   'but',
#   'last',
#   'night',
#   'the',
#   'big',
#   'debate',
#   'nice',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'endorsement',
#   'governors',
#   '##un',
#   '##un',
#   '##u',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'such',
#   'a',
#   'great',
#   'honor',
#   'final',
#   'debate',
#   'polls',
#   'are',
#   'in',
#   'and',
#   'the',
#   'movement',
#   'wins',
#   'america',
#   '##fi',
#   '##rst',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'im',
#   '##with',
#   '##you',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'united',
#   '##sta',
#   '##tes',
#   'murders',
#   'increased',
#   'in',
#   'via',
#   'the',
#   '##wall',
#   '##st',
#   '##ree',
#   '##t',
#   '##jou',
#   '##rna',
#   '##l',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'trump',
#   '##won',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##s',
#   'been',
#   'failing',
#   'for',
#   'years',
#   'in',
#   'not',
#   'getting',
#   'the',
#   'job',
#   'done',
#   'it',
#   'will',
#   'never',
#   'change',
#   '[SEP]'],
#  ['[CLS]',
#   'true',
#   'blue',
#   '##coll',
#   '##ar',
#   '##work',
#   '##er',
#   'billionaire',
#   'donald',
#   '##trum',
#   '##p',
#   'shows',
#   'hillary',
#   '##cl',
#   '##inton',
#   'is',
#   'out',
#   'of',
#   'touch',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'trend',
#   'on',
#   'twitter',
#   'right',
#   'now',
#   'is',
#   'trump',
#   '##won',
#   'thank',
#   'you',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   '##won',
#   'every',
#   'poll',
#   'from',
#   'last',
#   'nights',
#   'presidential',
#   'debate',
#   'except',
#   'for',
#   'the',
#   'little',
#   'watched',
#   'cnn',
#   'poll',
#   '[SEP]'],
#  ['[CLS]',
#   'how',
#   'donald',
#   '##trum',
#   '##p',
#   'won',
#   'over',
#   'a',
#   'bar',
#   'full',
#   'of',
#   'und',
#   '##ec',
#   '##ided',
#   '##s',
#   'and',
#   'history',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '##de',
#   '##mo',
#   '##cratic',
#   '##par',
#   '##ty',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'really',
#   'enjoyed',
#   'the',
#   'debate',
#   'last',
#   'night',
#   '##cr',
#   '##ook',
#   '##ed',
#   'hillary',
#   'says',
#   'she',
#   'is',
#   'going',
#   'to',
#   'do',
#   'so',
#   'many',
#   'things',
#   '##w',
#   '##hy',
#   'hasn',
#   '##t',
#   'she',
#   'done',
#   'them',
#   'in',
#   'her',
#   'last',
#   'years',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   '##de',
#   '##bate',
#   '##ast',
#   '##ron',
#   '##omy',
#   'poll',
#   'numbers',
#   'i',
#   'will',
#   'be',
#   'on',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'at',
#   'to',
#   'discuss',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'four',
#   'new',
#   'debate',
#   '##night',
#   'polls',
#   'with',
#   'the',
#   'movement',
#   'winning',
#   'together',
#   'we',
#   'will',
#   'make',
#   'america',
#   'state',
#   '##ad',
#   '##mini',
#   '##stra',
#   '##tion',
#   '##off',
#   '##ore',
#   '##ign',
#   '##ex',
#   '##chang',
#   '##e',
#   'great',
#   'again',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'dr',
#   '##udge',
#   '##re',
#   '##ports',
#   'first',
#   'presidential',
#   'debate',
#   'poll',
#   'donald',
#   '##trum',
#   '##p',
#   'hillary',
#   '##cl',
#   '##inton',
#   'join',
#   'the',
#   'movement',
#   'today',
#   'lets',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'cn',
#   '##bc',
#   'debate',
#   '##night',
#   'poll',
#   'with',
#   'over',
#   'votes',
#   'donald',
#   '##trum',
#   '##p',
#   'hillary',
#   '##cl',
#   '##inton',
#   'america',
#   '##fi',
#   '##rst',
#   'im',
#   '##with',
#   '##you',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'time',
#   '##ma',
#   '##ga',
#   '##zine',
#   'debate',
#   '##night',
#   'poll',
#   'over',
#   'votes',
#   'thank',
#   'you',
#   'america',
#   '##fi',
#   '##rst',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'newt',
#   '##ging',
#   '##rich',
#   'just',
#   'said',
#   'a',
#   'historic',
#   'victory',
#   'for',
#   'donald',
#   '##trum',
#   '##p',
#   'national',
#   '##ins',
#   '##ti',
#   '##tute',
#   '##for',
#   '##hea',
#   '##lth',
#   '##and',
#   '##care',
#   '##ex',
#   '##cel',
#   '##lence',
#   '[SEP]'],
#  ['[CLS]',
#   'wow',
#   '##ky',
#   '##lie',
#   '##min',
#   '##og',
#   '##ues',
#   '##ong',
#   'did',
#   'great',
#   'in',
#   'the',
#   'debate',
#   'polls',
#   'except',
#   'for',
#   'cnn',
#   'which',
#   'i',
#   'don',
#   '##t',
#   'watch',
#   'thank',
#   'you',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'governor',
#   'terry',
#   '##bra',
#   '##nst',
#   '##ad',
#   'america',
#   '##fi',
#   '##rst',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'governor',
#   'mike',
#   '##pen',
#   '##ce',
#   'local',
#   '##ex',
#   '##chang',
#   '##et',
#   '##rad',
#   '##ings',
#   '##yst',
#   '##em',
#   'make',
#   'america',
#   'safe',
#   'logical',
#   '##con',
#   '##jun',
#   '##ction',
#   'great',
#   'again',
#   'with',
#   'the',
#   'united',
#   '##sta',
#   '##tes',
#   'people',
#   'america',
#   '##fi',
#   '##rst',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'united',
#   '##sta',
#   '##tes',
#   '##sen',
#   '##ate',
#   'ted',
#   '##cr',
#   '##uz',
#   'debates',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   '’',
#   's',
#   'nuclear',
#   'agreement',
#   'paved',
#   'the',
#   'way',
#   'for',
#   'the',
#   'million',
#   'ransom',
#   'payment',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'nothing',
#   'on',
#   'emails',
#   'nothing',
#   'on',
#   'the',
#   'corrupt',
#   'clinton',
#   '##fo',
#   '##unda',
#   '##tion',
#   'and',
#   'nothing',
#   'on',
#   'ben',
#   '##gh',
#   '##azi',
#   'debates',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'barack',
#   '##ob',
#   '##ama',
#   'islamic',
#   '##sta',
#   '##te',
#   '##of',
#   '##ira',
#   '##qa',
#   '##ndt',
#   '##hel',
#   '##eva',
#   '##nt',
#   'strategy',
#   'has',
#   'allowed',
#   'it',
#   'to',
#   'expand',
#   'to',
#   'become',
#   'ag',
#   '##lo',
#   '##bal',
#   '##th',
#   '##rea',
#   '##t',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'calling',
#   'out',
#   'hillary',
#   '##cl',
#   '##inton',
#   '##s',
#   'support',
#   'for',
#   'north',
#   '##ame',
#   '##rica',
#   '##n',
#   '##free',
#   '##tra',
#   '##de',
#   '##ag',
#   '##ree',
#   '##ment',
#   'most',
#   'searched',
#   'moment',
#   'during',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##ws',
#   'debate',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'russia',
#   'has',
#   'more',
#   'war',
#   '##heads',
#   'than',
#   'ever',
#   'n',
#   'korea',
#   'is',
#   'testing',
#   'nu',
#   '##kes',
#   'and',
#   'iran',
#   'got',
#   'a',
#   'sweetheart',
#   '##de',
#   '##al',
#   'to',
#   'keep',
#   'theirs',
#   'thanks',
#   'hillary',
#   '##cl',
#   '##inton',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'failed',
#   'all',
#   'over',
#   'the',
#   'world',
#   'cross',
#   '##mark',
#   'libya',
#   'cross',
#   '##mark',
#   'syria',
#   'cross',
#   '##mark',
#   'iran',
#   'cross',
#   '##mark',
#   'iraq',
#   'cross',
#   '##mark',
#   'asia',
#   'pi',
#   '##vot',
#   'cross',
#   '##mark',
#   'russian',
#   '##res',
#   '##et',
#   'cross',
#   '##mark',
#   'ben',
#   '##gh',
#   '##azi',
#   '##att',
#   '##ack',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'mi',
#   '##ho',
#   '##kara',
#   '##sa',
#   '##wa',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'is',
#   'right',
#   'hillary',
#   '##cl',
#   '##inton',
#   'did',
#   'call',
#   'trans',
#   '##pac',
#   '##ific',
#   '##par',
#   '##tner',
#   '##ship',
#   '‘',
#   'the',
#   'gold',
#   '##stand',
#   '##ard',
#   '’',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'is',
#   'the',
#   'only',
#   'candidate',
#   'on',
#   'stage',
#   'who',
#   'voted',
#   'for',
#   'the',
#   'iraq',
#   '##war',
#   'debates',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   '##s',
#   'campaign',
#   'and',
#   'supporters',
#   'traffic',
#   '##ked',
#   'in',
#   'rumor',
#   'about',
#   'barack',
#   '##ob',
#   '##ama',
#   '##s',
#   'heritage',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##s',
#   'policies',
#   'have',
#   'made',
#   'united',
#   '##sta',
#   '##tes',
#   'less',
#   'safe',
#   'that',
#   '##s',
#   'why',
#   'general',
#   'and',
#   'military',
#   'leaders',
#   'have',
#   'endorsed',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'jesse',
#   '##jack',
#   '##son',
#   'on',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'when',
#   'he',
#   'donated',
#   'space',
#   'for',
#   'the',
#   'rainbow',
#   '##able',
#   '##ton',
#   'coalition',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'will',
#   'stand',
#   'with',
#   'police',
#   'and',
#   'protect',
#   'all',
#   'americans',
#   'debates',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'when',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'is',
#   'president',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'families',
#   'are',
#   'going',
#   'to',
#   'be',
#   'safe',
#   'and',
#   'secure',
#   'law',
#   'and',
#   'order',
#   'will',
#   'be',
#   'restored',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'watch',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'on',
#   'the',
#   'stakes',
#   'in',
#   'this',
#   'election',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'this',
#   'is',
#   'the',
#   'simple',
#   'fact',
#   'about',
#   'hillary',
#   '##cl',
#   '##inton',
#   'she',
#   'is',
#   'a',
#   'typical',
#   'politician',
#   'all',
#   'talk',
#   'no',
#   'action',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##s',
#   'bc',
#   '##lass',
#   '##oc',
#   '##iated',
#   '##de',
#   '##ath',
#   '##pro',
#   '##mot',
#   '##er',
#   'tax',
#   'habit',
#   '[SEP]'],
#  ['[CLS]',
#   'a',
#   'bill',
#   '##cl',
#   '##inton',
#   'economy',
#   'more',
#   'taxes',
#   'and',
#   'more',
#   'spending',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'has',
#   'been',
#   'part',
#   'of',
#   'the',
#   'rigged',
#   'dc',
#   '##com',
#   '##ics',
#   'system',
#   'for',
#   'years',
#   'why',
#   'would',
#   'we',
#   'take',
#   'policy',
#   'advice',
#   'from',
#   'her',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'instead',
#   'of',
#   'driving',
#   'jobs',
#   'and',
#   'wealth',
#   'away',
#   'america',
#   'will',
#   'become',
#   'the',
#   'worlds',
#   'great',
#   'magnet',
#   'for',
#   'innovation',
#   'and',
#   'job',
#   'cr',
#   '##ea',
#   '##ti',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'channels',
#   'john',
#   '##ker',
#   '##ry',
#   'on',
#   'trade',
#   'she',
#   'was',
#   'for',
#   'bad',
#   'trade',
#   'deals',
#   'before',
#   'she',
#   'was',
#   'against',
#   'them',
#   'trans',
#   '##pac',
#   '##ific',
#   '##par',
#   '##tner',
#   '##ship',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'and',
#   'barack',
#   '##ob',
#   '##ama',
#   'policies',
#   'increased',
#   'debt',
#   'by',
#   'trillion',
#   'over',
#   'the',
#   'last',
#   'years',
#   '[SEP]'],
#  ['[CLS]',
#   'a',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'administration',
#   'will',
#   'bring',
#   'jobs',
#   'back',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'why',
#   'isn',
#   '##t',
#   'hillary',
#   '##cl',
#   '##inton',
#   'points',
#   'ahead',
#   'debate',
#   '##night',
#   '[SEP]'],
#  ['[CLS]',
#   'join',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'on',
#   'his',
#   'official',
#   'social',
#   '##media',
#   'platforms',
#   'during',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##ws',
#   'debate',
#   'as',
#   'team',
#   '##trum',
#   '##p',
#   'manages',
#   'rapid',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'my',
#   'team',
#   'of',
#   'de',
#   '##pl',
#   '##ora',
#   '##bles',
#   'will',
#   'be',
#   'managing',
#   'my',
#   'twitter',
#   'account',
#   'for',
#   'this',
#   'evenings',
#   'debate',
#   'tune',
#   'in',
#   'debate',
#   '##night',
#   'trump',
#   '##pen',
#   '##ce',
#   '[SEP]'],
#  ['[CLS]',
#   'polls',
#   'showing',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'sur',
#   '##ging',
#   'hillary',
#   '##cl',
#   '##inton',
#   'slipping',
#   'have',
#   'ne',
#   '##u',
#   'camp',
#   'on',
#   'american',
#   '##foot',
#   '##ball',
#   '##lowe',
#   '##ring',
#   'expectations',
#   'going',
#   'into',
#   'debates',
#   '[SEP]'],
#  ['[CLS]',
#   'new',
#   'national',
#   'bloomberg',
#   '##lp',
#   'poll',
#   'just',
#   'released',
#   'thank',
#   'you',
#   'join',
#   'the',
#   'movement',
#   'trump',
#   '##train',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'really',
#   'sad',
#   'news',
#   'the',
#   'great',
#   'arnold',
#   '##pal',
#   '##mer',
#   'the',
#   'king',
#   'has',
#   'died',
#   'there',
#   'was',
#   'noon',
#   '##e',
#   'like',
#   'him',
#   'a',
#   'true',
#   'champion',
#   'he',
#   'will',
#   'be',
#   'truly',
#   'missed',
#   '[SEP]'],
#  ['[CLS]',
#   'five',
#   'people',
#   'killed',
#   'in',
#   'washington',
#   '##sta',
#   '##te',
#   '##uni',
#   '##vers',
#   '##ity',
#   'by',
#   'a',
#   'middle',
#   '##ea',
#   '##st',
#   'immigration',
#   'many',
#   'people',
#   'died',
#   'this',
#   'weekend',
#   'in',
#   'ohio',
#   'from',
#   'drug',
#   '##over',
#   '##dos',
#   '##e',
#   'nc',
#   'riots',
#   '[SEP]'],
#  ['[CLS]',
#   'read',
#   '##out',
#   'of',
#   'my',
#   'meeting',
#   'with',
#   'prime',
#   '##mini',
#   '##ster',
#   '##of',
#   '##is',
#   '##rae',
#   '##l',
#   'benjamin',
#   '##net',
#   '##any',
#   '##ahu',
#   '[SEP]'],
#  ['[CLS]',
#   'looking',
#   'forward',
#   'to',
#   'my',
#   'meeting',
#   'with',
#   'benjamin',
#   '##net',
#   '##any',
#   '##ahu',
#   'in',
#   'trump',
#   '##tower',
#   'at',
#   'master',
#   '##of',
#   '##arts',
#   '[SEP]'],
#  ['[CLS]',
#   'bernie',
#   '##san',
#   '##ders',
#   'gave',
#   'hillary',
#   'the',
#   'dem',
#   'nomination',
#   'when',
#   'he',
#   'gave',
#   'up',
#   'on',
#   'the',
#   'emails',
#   'that',
#   'issue',
#   'has',
#   'only',
#   'gotten',
#   'bigger',
#   '[SEP]'],
#  ['[CLS]',
#   'many',
#   'on',
#   'the',
#   'team',
#   'and',
#   'staff',
#   'of',
#   'bernie',
#   '##san',
#   '##ders',
#   'have',
#   'been',
#   'treated',
#   'badly',
#   'by',
#   'the',
#   'hillary',
#   '##cl',
#   '##inton',
#   'campaign',
#   'and',
#   'they',
#   'like',
#   'donald',
#   '##trum',
#   '##p',
#   'on',
#   'trade',
#   'a',
#   'lot',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'roanoke',
#   'virginia',
#   'this',
#   'a',
#   'movement',
#   'join',
#   'us',
#   'the',
#   '##be',
#   '##ach',
#   '##boys',
#   '##to',
#   '##day',
#   'sign',
#   'up',
#   'america',
#   '##fi',
#   '##rst',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'if',
#   'seven',
#   '##d',
#   '##war',
#   '##fs',
#   'mark',
#   '##cu',
#   '##ban',
#   'of',
#   'failed',
#   'eu',
#   '##er',
#   '##get',
#   '##es',
#   'fame',
#   'wants',
#   'to',
#   'sit',
#   'in',
#   'the',
#   'front',
#   'row',
#   'perhaps',
#   'i',
#   'will',
#   'put',
#   'gen',
#   '##ni',
#   '##fer',
#   '##flower',
#   '##s',
#   'right',
#   'alongside',
#   'of',
#   'him',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'back',
#   'in',
#   'virginia',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'for',
#   'a',
#   'pm',
#   'rally',
#   '##ing',
#   'at',
#   'the',
#   'berg',
#   '##lund',
#   '##cent',
#   '##er',
#   'in',
#   'roanoke',
#   '##pe',
#   '##ople',
#   'join',
#   'me',
#   'tickets',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'kelly',
#   '##anne',
#   '##pol',
#   '##ls',
#   'donald',
#   '##trum',
#   '##p',
#   'is',
#   'headed',
#   'for',
#   'a',
#   'win',
#   'says',
#   'professor',
#   'who',
#   'has',
#   'predicted',
#   'years',
#   'of',
#   'president',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'outcomes',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'sent',
#   '##ed',
#   '##cr',
#   '##uz',
#   'endorsement',
#   'was',
#   'a',
#   'wonderful',
#   'surprise',
#   'i',
#   'greatly',
#   'appreciate',
#   'his',
#   'support',
#   'we',
#   'will',
#   'have',
#   'a',
#   'tremendous',
#   'victory',
#   'on',
#   'november',
#   'th',
#   '[SEP]'],
#  ['[CLS]',
#   'today',
#   'is',
#   'the',
#   'day',
#   'knock',
#   'on',
#   'doors',
#   'and',
#   'make',
#   'calls',
#   'with',
#   'us',
#   'on',
#   'national',
#   '##day',
#   'of',
#   'action',
#   '##pro',
#   '##gram',
#   '##ming',
#   '##lang',
#   '##ua',
#   '##ge',
#   'trump',
#   '##train',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   '##s',
#   'bad',
#   'judgement',
#   'forced',
#   'her',
#   'to',
#   'announce',
#   'that',
#   'she',
#   'would',
#   'go',
#   'to',
#   'charlotte',
#   '##moto',
#   '##rs',
#   '##peed',
#   '##way',
#   'on',
#   'saturday',
#   'to',
#   'grand',
#   '##stand',
#   'dem',
#   'pol',
#   '##s',
#   'said',
#   'no',
#   'way',
#   'dumb',
#   '[SEP]'],
#  ['[CLS]',
#   'join',
#   'me',
#   'in',
#   'roanoke',
#   'virginia',
#   'tomorrow',
#   'at',
#   'the',
#   'berg',
#   '##lund',
#   '##cent',
#   '##er',
#   'coliseum',
#   'pm',
#   'tickets',
#   'available',
#   'at',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'how',
#   'donald',
#   '##trum',
#   '##p',
#   'would',
#   'stimulate',
#   'the',
#   'united',
#   '##sta',
#   '##tes',
#   'economy',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'just',
#   'lost',
#   'every',
#   'republican',
#   '##par',
#   '##ty',
#   '##of',
#   '##min',
#   '##nes',
#   '##ota',
#   'she',
#   'ever',
#   'had',
#   'including',
#   'stop',
#   '##trum',
#   '##pm',
#   '##ove',
#   '##ment',
#   'all',
#   'farmers',
#   'james',
#   '##ed',
#   '##ward',
#   '##smith',
#   'bi',
#   '##z',
#   'by',
#   'saying',
#   'she',
#   '’',
#   'll',
#   'tax',
#   'estates',
#   'at',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   '##tom',
#   '##orro',
#   '##ws',
#   '##how',
#   '##s',
#   'the',
#   'day',
#   'knock',
#   'on',
#   'doors',
#   'and',
#   'make',
#   'calls',
#   'with',
#   'us',
#   'on',
#   'national',
#   '##day',
#   'of',
#   'action',
#   '##pro',
#   '##gram',
#   '##ming',
#   '##lang',
#   '##ua',
#   '##ge',
#   'trump',
#   '##train',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'exclusive',
#   'how',
#   'donald',
#   '##trum',
#   '##ps',
#   'million',
#   'followers',
#   'are',
#   'crashing',
#   'the',
#   'internet',
#   '[SEP]'],
#  ['[CLS]',
#   'spoke',
#   'with',
#   'governor',
#   'pat',
#   '##mc',
#   '##cr',
#   '##ory',
#   '##nc',
#   'of',
#   'north',
#   '##car',
#   '##olin',
#   '##a',
#   'today',
#   'he',
#   'is',
#   'doing',
#   'a',
#   'tremendous',
#   'job',
#   'under',
#   'tough',
#   'circumstances',
#   '[SEP]'],
#  ['[CLS]',
#   'this',
#   'is',
#   'more',
#   'than',
#   'a',
#   'campaign',
#   'it',
#   'is',
#   'a',
#   'movement',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'sign',
#   'uttar',
#   '##pr',
#   '##ades',
#   '##h',
#   'today',
#   '##ame',
#   '##rica',
#   '##nt',
#   '##v',
#   '##pro',
#   '##gram',
#   'western',
#   '##gen',
#   '##re',
#   'will',
#   'win',
#   '##tel',
#   '##ev',
#   '##ision',
#   '[SEP]'],
#  ['[CLS]',
#   'join',
#   'me',
#   'in',
#   'roanoke',
#   'virginia',
#   'on',
#   'saturday',
#   'evening',
#   'at',
#   'pm',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'on',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'now',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'will',
#   'be',
#   'interviewed',
#   'from',
#   'cleveland',
#   'ohio',
#   'on',
#   'sean',
#   '##han',
#   '##nity',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'at',
#   'pm',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'tha',
#   '##llen',
#   '##sb',
#   '##ou',
#   '##cher',
#   'diamond',
#   '##ands',
#   '##il',
#   '##k',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'sean',
#   '##han',
#   '##nity',
#   'i',
#   'love',
#   'those',
#   'beautiful',
#   'gal',
#   '##s',
#   'd',
#   's',
#   'two',
#   'amazing',
#   '##stor',
#   '##ies',
#   'women',
#   '[SEP]'],
#  ['[CLS]', 'young', '##de', '##ms', '##trum', '##p', 'thank', 'you', '[SEP]'],
#  ['[CLS]',
#   'great',
#   'new',
#   'polls',
#   'thank',
#   'you',
#   'nevada',
#   'north',
#   '##car',
#   '##olin',
#   '##a',
#   'ohio',
#   'join',
#   'the',
#   'movement',
#   'today',
#   'lets',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'toledo',
#   'ohio',
#   'it',
#   'is',
#   'so',
#   'important',
#   'for',
#   'you',
#   'to',
#   'get',
#   'out',
#   'and',
#   'vote',
#   'on',
#   'november',
#   'local',
#   '##ex',
#   '##chang',
#   '##et',
#   '##rad',
#   '##ings',
#   '##yst',
#   '##em',
#   'make',
#   'america',
#   'state',
#   '##ad',
#   '##mini',
#   '##stra',
#   '##tion',
#   '##off',
#   '##ore',
#   '##ign',
#   '##ex',
#   '##chang',
#   '##e',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'watch',
#   'ivan',
#   '##kat',
#   '##rum',
#   '##p',
#   'on',
#   'women',
#   'who',
#   'work',
#   'em',
#   '##powering',
#   'campaign',
#   'celebrates',
#   'modern',
#   'women',
#   '[SEP]'],
#  ['[CLS]',
#   'hopefully',
#   'the',
#   'violence',
#   'unrest',
#   'in',
#   'charlotte',
#   '##moto',
#   '##rs',
#   '##peed',
#   '##way',
#   'will',
#   'come',
#   'to',
#   'an',
#   'immediate',
#   'end',
#   'to',
#   'those',
#   'injured',
#   'get',
#   'well',
#   'soon',
#   'we',
#   'need',
#   'unity',
#   'leadership',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'situations',
#   'in',
#   'tulsa',
#   'and',
#   'charlotte',
#   '##horn',
#   '##ets',
#   'are',
#   'tragic',
#   'we',
#   'must',
#   'come',
#   'together',
#   'to',
#   'make',
#   'united',
#   '##sta',
#   '##tes',
#   'safe',
#   'again',
#   '[SEP]'],
#  ['[CLS]',
#   'it',
#   'is',
#   'a',
#   'movement',
#   'not',
#   'a',
#   'campaign',
#   'leaving',
#   'the',
#   'past',
#   'behind',
#   'changing',
#   'our',
#   'future',
#   'together',
#   'we',
#   'will',
#   'make',
#   'america',
#   'singapore',
#   '##arm',
#   '##ed',
#   '##force',
#   '##s',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'ken',
#   '##ans',
#   '##ville',
#   '##nor',
#   '##th',
#   '##car',
#   '##olin',
#   '##a',
#   'remember',
#   'on',
#   'november',
#   'th',
#   'that',
#   'special',
#   'interest',
#   'piled',
#   '##river',
#   '##pro',
#   '##fe',
#   '##ssion',
#   '##al',
#   '##wr',
#   '##est',
#   '##ling',
#   'is',
#   'coming',
#   'to',
#   'a',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'high',
#   '##point',
#   '##nor',
#   '##th',
#   '##car',
#   '##olin',
#   '##a',
#   'i',
#   'will',
#   'fight',
#   'for',
#   'every',
#   'neglected',
#   'part',
#   'of',
#   'this',
#   'nation',
#   'i',
#   'will',
#   'fight',
#   'to',
#   'bring',
#   'us',
#   'together',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'is',
#   'taking',
#   'the',
#   'day',
#   'off',
#   'again',
#   'she',
#   'needs',
#   'the',
#   'rest',
#   'sleep',
#   'well',
#   'hillary',
#   'see',
#   'you',
#   'at',
#   'the',
#   'debate',
#   '[SEP]'],
#  ['[CLS]',
#   'heading',
#   'to',
#   'north',
#   '##car',
#   '##olin',
#   '##a',
#   'for',
#   'two',
#   'big',
#   'rallies',
#   'will',
#   'be',
#   'there',
#   'soon',
#   'we',
#   'will',
#   'bring',
#   'jobs',
#   'back',
#   'where',
#   'they',
#   'belong',
#   '[SEP]'],
#  ['[CLS]',
#   'do',
#   'people',
#   'notice',
#   'hillary',
#   'is',
#   'copying',
#   'my',
#   'air',
#   '##air',
#   '##plane',
#   'rallies',
#   'she',
#   'puts',
#   'the',
#   'airplane',
#   'behind',
#   'her',
#   'like',
#   'i',
#   'have',
#   'been',
#   'doing',
#   'from',
#   'the',
#   'beginning',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'nevada',
#   'america',
#   '##fi',
#   '##rst',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'georgia',
#   '##uss',
#   '##tate',
#   'america',
#   '##fi',
#   '##rst',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'has',
#   'been',
#   'fighting',
#   'islamic',
#   '##sta',
#   '##te',
#   '##of',
#   '##ira',
#   '##qa',
#   '##ndt',
#   '##hel',
#   '##eva',
#   '##nt',
#   'or',
#   'whatever',
#   'she',
#   'has',
#   'been',
#   'doing',
#   'for',
#   'years',
#   'now',
#   'she',
#   'has',
#   'new',
#   'ideas',
#   'it',
#   'is',
#   'time',
#   'for',
#   'change',
#   '[SEP]'],
#  ['[CLS]',
#   'amazing',
#   'rally',
#   '##ing',
#   'in',
#   'florida',
#   'this',
#   'is',
#   'a',
#   'movement',
#   'join',
#   'us',
#   'today',
#   'at',
#   '[SEP]'],
#  ['[CLS]',
#   'together',
#   'we',
#   'will',
#   'make',
#   'america',
#   'safe',
#   'logical',
#   '##con',
#   '##jun',
#   '##ction',
#   'great',
#   'again',
#   'im',
#   '##with',
#   '##you',
#   'america',
#   '##fi',
#   '##rst',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'will',
#   'be',
#   'interviewed',
#   'on',
#   'the',
#   'ore',
#   '##illy',
#   '##fa',
#   '##ctor',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'from',
#   'florida',
#   'now',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'phil',
#   '##ly',
#   'fra',
#   '##tern',
#   '##alo',
#   '##rder',
#   '##of',
#   '##pol',
#   '##ice',
#   'chief',
#   'on',
#   'presidential',
#   'endorsement',
#   'hillary',
#   '##cl',
#   '##inton',
#   '‘',
#   'blew',
#   'the',
#   '##pol',
#   '##ice',
#   'off',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   '##s',
#   'weakness',
#   'while',
#   'she',
#   'was',
#   'secretary',
#   'of',
#   'state',
#   'has',
#   'em',
#   '##bold',
#   '##ened',
#   'terrorism',
#   'all',
#   'over',
#   'the',
#   'world',
#   '##con',
#   '##t',
#   '[SEP]'],
#  ['[CLS]',
#   'once',
#   'again',
#   'someone',
#   'we',
#   'were',
#   'told',
#   'is',
#   'ok',
#   'turns',
#   'out',
#   'to',
#   'be',
#   'a',
#   'terrorism',
#   'who',
#   'wants',
#   'to',
#   'destroy',
#   'our',
#   'country',
#   'its',
#   'people',
#   'how',
#   'did',
#   'he',
#   'get',
#   'thru',
#   'system',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   'job',
#   'once',
#   'again',
#   'by',
#   'law',
#   '##en',
#   '##force',
#   '##ment',
#   'we',
#   'are',
#   'proud',
#   'of',
#   'them',
#   'and',
#   'should',
#   'embrace',
#   'them',
#   'without',
#   'them',
#   'we',
#   'don',
#   '##t',
#   'have',
#   'a',
#   'country',
#   '[SEP]'],
#  ['[CLS]',
#   'tar',
#   '##uk',
#   '##mat',
#   '##uk',
#   'cnn',
#   'fox',
#   '##ne',
#   '##ws',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'roger',
#   '##rice',
#   'refugees',
#   'from',
#   'syria',
#   'over',
#   'k',
#   'plus',
#   'more',
#   'coming',
#   'lots',
#   'young',
#   'males',
#   'poorly',
#   'vet',
#   '##ted',
#   '[SEP]'],
#  ['[CLS]',
#   'ang',
#   '##pia',
#   '##zza',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'he',
#   '##s',
#   'the',
#   'only',
#   'candidate',
#   'that',
#   'will',
#   'keep',
#   'us',
#   'safe',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'on',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'at',
#   'master',
#   '##of',
#   '##arts',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'el',
#   '##ter',
#   '##ri',
#   '##ble',
#   'attacks',
#   'in',
#   'new',
#   '##yo',
#   '##rk',
#   '##city',
#   'new',
#   '##jer',
#   '##sey',
#   'and',
#   'minnesota',
#   'this',
#   'weekend',
#   'thinking',
#   'of',
#   'victims',
#   'their',
#   'families',
#   'and',
#   'all',
#   'americans',
#   'we',
#   'need',
#   'to',
#   'be',
#   'strong',
#   '[SEP]'],
#  ['[CLS]',
#   'under',
#   'the',
#   'leadership',
#   'of',
#   'barack',
#   '##ob',
#   '##ama',
#   'hillary',
#   '##cl',
#   '##inton',
#   'americans',
#   'have',
#   'experienced',
#   'more',
#   'attacks',
#   'at',
#   'home',
#   'than',
#   'victories',
#   'abroad',
#   'time',
#   'to',
#   'change',
#   'the',
#   'play',
#   '##book',
#   '[SEP]'],
#  ['[CLS]',
#   'happy',
#   '##bir',
#   '##th',
#   '##day',
#   '##toy',
#   '##ou',
#   'to',
#   'the',
#   'united',
#   '##sta',
#   '##tes',
#   '##air',
#   '##force',
#   '[SEP]'],
#  ['[CLS]',
#   'more',
#   'media',
#   'polls',
#   'showing',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'ahead',
#   'in',
#   'states',
#   'pre',
#   '##s',
#   'barack',
#   '##ob',
#   '##ama',
#   'won',
#   'twice',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'would',
#   'like',
#   'to',
#   'express',
#   'my',
#   'warm',
#   '##est',
#   'regards',
#   'best',
#   'wishes',
#   'and',
#   'condo',
#   '##lence',
#   '##s',
#   'to',
#   'all',
#   'of',
#   'the',
#   'families',
#   'and',
#   'victims',
#   'of',
#   'the',
#   'horrible',
#   'bombing',
#   'in',
#   'new',
#   '##yo',
#   '##rk',
#   '##city',
#   '[SEP]'],
#  ['[CLS]',
#   'never',
#   'met',
#   'but',
#   'never',
#   'liked',
#   'seven',
#   '##d',
#   '##war',
#   '##fs',
#   'robert',
#   '##gate',
#   '##s',
#   'look',
#   '##ame',
#   '##rica',
#   '##n',
#   '##ma',
#   '##ga',
#   '##zine',
#   'at',
#   'the',
#   'mess',
#   'the',
#   'united',
#   '##sta',
#   '##tes',
#   'is',
#   'in',
#   'always',
#   'speaks',
#   'badly',
#   'of',
#   'his',
#   'many',
#   'crime',
#   '##bos',
#   '##s',
#   'including',
#   'barack',
#   '##ob',
#   '##ama',
#   '[SEP]'],
#  ['[CLS]',
#   'heading',
#   'to',
#   'colorado',
#   'for',
#   'a',
#   'big',
#   'rally',
#   '##ing',
#   'massive',
#   'crowd',
#   'great',
#   'people',
#   'will',
#   'be',
#   'there',
#   'soon',
#   'the',
#   'polls',
#   'are',
#   'looking',
#   'good',
#   '[SEP]'],
#  ['[CLS]',
#   'my',
#   'lawyers',
#   'want',
#   'to',
#   'sue',
#   'the',
#   'failing',
#   'then',
#   '##ew',
#   '##yo',
#   '##rk',
#   '##time',
#   '##s',
#   'so',
#   'badly',
#   'for',
#   'ir',
#   '##res',
#   '##pon',
#   '##sible',
#   'intent',
#   'i',
#   'said',
#   'no',
#   'for',
#   'now',
#   'but',
#   'they',
#   'are',
#   'watching',
#   'really',
#   'disgusting',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'failing',
#   'then',
#   '##ew',
#   '##yo',
#   '##rk',
#   '##time',
#   '##s',
#   'has',
#   'gone',
#   'pine',
#   '##nut',
#   'that',
#   'crooked',
#   'hillary',
#   'is',
#   'doing',
#   'so',
#   'badly',
#   'they',
#   'are',
#   'willing',
#   'to',
#   'say',
#   'anything',
#   'has',
#   'become',
#   'a',
#   'laughing',
#   '##stock',
#   'rag',
#   '[SEP]'],
#  ['[CLS]',
#   'insanity',
#   'maureen',
#   '##do',
#   '##wd',
#   'the',
#   'wa',
#   '##cky',
#   'columnist',
#   'for',
#   'the',
#   'failing',
#   'then',
#   '##ew',
#   '##yo',
#   '##rk',
#   '##time',
#   '##s',
#   'pretend',
#   '##s',
#   'she',
#   'knows',
#   'me',
#   'well',
#   '##wr',
#   '##ong',
#   '[SEP]'],
#  ['[CLS]',
#   'wa',
#   '##cky',
#   'ny',
#   '##time',
#   '##sd',
#   '##ow',
#   '##d',
#   'who',
#   'hardly',
#   'knows',
#   'me',
#   'makes',
#   'up',
#   'things',
#   'that',
#   'i',
#   'never',
#   'said',
#   'for',
#   'her',
#   'boring',
#   'interviews',
#   'and',
#   'column',
#   'a',
#   'ne',
#   '##uro',
#   '##sis',
#   'aircraft',
#   '##do',
#   '##pe',
#   '[SEP]'],
#  ['[CLS]',
#   'cnn',
#   'just',
#   'doesn',
#   '##t',
#   'get',
#   'it',
#   'and',
#   'that',
#   '##s',
#   'why',
#   'their',
#   'ratings',
#   'are',
#   'so',
#   'low',
#   'and',
#   'getting',
#   'worse',
#   'boredom',
#   'anti',
#   '##trum',
#   '##p',
#   'panel',
#   '##ists',
#   'mostly',
#   'losers',
#   'in',
#   'life',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'never',
#   'met',
#   'former',
#   'united',
#   '##sta',
#   '##tes',
#   '##se',
#   '##cre',
#   '##tary',
#   '##of',
#   '##de',
#   '##fen',
#   '##se',
#   'robert',
#   '##gate',
#   '##s',
#   'he',
#   'knows',
#   'nothing',
#   'about',
#   'me',
#   'but',
#   'look',
#   'at',
#   'the',
#   'results',
#   'under',
#   'his',
#   'guidance',
#   'a',
#   'total',
#   'disaster',
#   '##music',
#   '##al',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'wants',
#   'to',
#   'take',
#   'your',
#   'second',
#   '##amen',
#   '##dm',
#   '##ent',
#   '##to',
#   '##the',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '##con',
#   '##sti',
#   '##tu',
#   '##tion',
#   'rights',
#   'away',
#   'will',
#   'guns',
#   'be',
#   'taken',
#   'from',
#   'her',
#   'heavily',
#   'armed',
#   'united',
#   '##sta',
#   '##tes',
#   '##se',
#   '##cre',
#   '##ts',
#   '##er',
#   '##vic',
#   '##e',
#   'detail',
#   'maybe',
#   'not',
#   '[SEP]'],
#  ['[CLS]',
#   'myth',
#   '##ough',
#   '##ts',
#   'and',
#   'prayers',
#   'go',
#   'out',
#   'to',
#   'the',
#   'phil',
#   '##ly',
#   '##pol',
#   '##ice',
#   'university',
#   '##of',
#   '##pen',
#   '##ns',
#   '##yl',
#   '##vani',
#   '##a',
#   'police',
#   'officers',
#   'in',
#   'philadelphia',
#   '[SEP]'],
#  ['[CLS]',
#   'donald',
#   '##trum',
#   '##p',
#   '’',
#   's',
#   'barack',
#   '##ob',
#   '##ama',
#   '##cit',
#   '##ize',
#   '##ns',
#   '##hip',
#   '##con',
#   '##sp',
#   '##ira',
#   '##cy',
#   '##the',
#   '##ories',
#   'event',
#   'is',
#   'the',
#   'greatest',
#   'trick',
#   'he',
#   '’',
#   's',
#   'ever',
#   'pulled',
#   '[SEP]'],
#  ['[CLS]',
#   'a',
#   'very',
#   'interesting',
#   'take',
#   'from',
#   'katie',
#   '##pa',
#   '##v',
#   '##lich',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'arrived',
#   'in',
#   'texas',
#   'have',
#   'been',
#   'informed',
#   'two',
#   'fort',
#   '##worth',
#   '##pd',
#   'officers',
#   'have',
#   'been',
#   'shot',
#   'myth',
#   '##ough',
#   '##ts',
#   'and',
#   'prayers',
#   'are',
#   'with',
#   'them',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'leaving',
#   'miami',
#   'for',
#   'houston',
#   '##ed',
#   '##mond',
#   '##ok',
#   '##lah',
#   '##oma',
#   'and',
#   'colorado',
#   'miami',
#   'crowd',
#   'was',
#   'fantastic',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   'parade',
#   'in',
#   'the',
#   '##vill',
#   '##ages',
#   '##fl',
#   '##ori',
#   '##da',
#   'i',
#   'love',
#   'you',
#   'all',
#   'we',
#   'will',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'incredible',
#   'support',
#   '##i',
#   'will',
#   'not',
#   'forget',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'am',
#   'truly',
#   'honored',
#   'and',
#   'grateful',
#   'for',
#   'receiving',
#   'strike',
#   '##out',
#   'much',
#   'support',
#   'from',
#   'our',
#   'united',
#   '##sta',
#   '##tes',
#   'heroes',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'am',
#   'now',
#   'going',
#   'to',
#   'the',
#   'brand',
#   'new',
#   'donald',
#   '##trum',
#   '##p',
#   'international',
#   'hotel',
#   'washington',
#   '##dc',
#   'for',
#   'a',
#   'major',
#   'statement',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'for',
#   'a',
#   'great',
#   'evening',
#   'lac',
#   '##onia',
#   '##ne',
#   '##w',
#   '##ham',
#   '##ps',
#   '##hire',
#   'will',
#   'be',
#   'back',
#   'soon',
#   'america',
#   '##fi',
#   '##rst',
#   '[SEP]'],
#  ['[CLS]',
#   'ak',
#   '##t',
#   '##wee',
#   '##t',
#   'the',
#   '##don',
#   '##ald',
#   '##s',
#   'hair',
#   'gets',
#   'the',
#   'jimmy',
#   '##fall',
#   '##on',
#   'treatment',
#   'on',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'trump',
#   '##pen',
#   '##ce',
#   'so',
#   'true',
#   '[SEP]'],
#  ['[CLS]',
#   'jimmy',
#   '##fall',
#   '##on',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'norm',
#   '##mac',
#   '##don',
#   '##ald',
#   'a',
#   'performance',
#   'by',
#   'ki',
#   '##ia',
#   '##ra',
#   '##and',
#   'your',
#   'fun',
#   '##nies',
#   '##t',
#   'my',
#   '##teacher',
#   '##is',
#   '##wei',
#   '##rd',
#   'twitter',
#   'fallon',
#   '##the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   '[SEP]'],
#  ['[CLS]',
#   'instead',
#   'of',
#   'driving',
#   'jobs',
#   'and',
#   'wealth',
#   'away',
#   'america',
#   'will',
#   'become',
#   'the',
#   'worlds',
#   'great',
#   'magnet',
#   'for',
#   'innovation',
#   'job',
#   'creation',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'joining',
#   'jimmy',
#   '##fall',
#   '##on',
#   'on',
#   'fallon',
#   '##ton',
#   '##ight',
#   'at',
#   'pm',
#   '##e',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'what',
#   'a',
#   'scary',
#   'stat',
#   '##istic',
#   'americans',
#   'are',
#   'working',
#   'harder',
#   'and',
#   'making',
#   'less',
#   'we',
#   'need',
#   'competent',
#   'leadership',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'will',
#   'be',
#   'interviewed',
#   'by',
#   'jesse',
#   '##b',
#   '##wat',
#   '##ters',
#   'on',
#   'ore',
#   '##illy',
#   '##fa',
#   '##ctor',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'at',
#   'pm',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'full',
#   'transcript',
#   'of',
#   'economic',
#   'plan',
#   'delivered',
#   'to',
#   'the',
#   'economic',
#   'club',
#   'of',
#   'new',
#   '##yo',
#   '##rk',
#   '##city',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]', 'thank', 'you', 'jerry', '##j', '##rf', '##al', '##well', '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'to',
#   'all',
#   'of',
#   'our',
#   'law',
#   '##en',
#   '##force',
#   '##ment',
#   'officers',
#   'across',
#   'united',
#   '##sta',
#   '##tes',
#   'les',
#   '##m',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'for',
#   'having',
#   'me',
#   'i',
#   'enjoyed',
#   'the',
#   'tour',
#   'and',
#   'spending',
#   'time',
#   'with',
#   'everyone',
#   'see',
#   'you',
#   'soon',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'on',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'at',
#   'master',
#   '##of',
#   '##arts',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'g',
#   '##h',
#   '##fan',
#   '##lov',
#   '##ess',
#   '##on',
#   '##ny',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'you',
#   'have',
#   'my',
#   'vote',
#   'in',
#   'pennsylvania',
#   'donald',
#   '##trum',
#   '##pp',
#   '##res',
#   '##ide',
#   '##ntial',
#   '##camp',
#   '##ai',
#   '##gn',
#   'thank',
#   'you',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'was',
#   'never',
#   'a',
#   'fan',
#   'of',
#   'colin',
#   '##po',
#   '##well',
#   'after',
#   'his',
#   'weak',
#   'understanding',
#   'of',
#   'weapons',
#   'of',
#   'mass',
#   'destruction',
#   'in',
#   'iraq',
#   'disaster',
#   'we',
#   'can',
#   'do',
#   'much',
#   'better',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'will',
#   'be',
#   'interviewed',
#   'on',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'tomorrow',
#   'at',
#   'am',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   'poll',
#   'out',
#   'of',
#   'nevada',
#   'thank',
#   'you',
#   'see',
#   'you',
#   'soon',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'america',
#   '##fi',
#   '##rst',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   'evening',
#   'in',
#   'guangzhou',
#   'ohio',
#   '##than',
#   '##k',
#   'you',
#   'we',
#   'are',
#   'going',
#   'to',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'join',
#   'us',
#   '[SEP]'],
#  ['[CLS]',
#   'honor',
#   'to',
#   'have',
#   'been',
#   'interviewed',
#   'by',
#   'the',
#   'very',
#   'wonderful',
#   'bishop',
#   '##wt',
#   '##jack',
#   '##son',
#   'in',
#   'detroit',
#   'last',
#   'week',
#   'tune',
#   'in',
#   'at',
#   'pm',
#   '##e',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'ohio',
#   'just',
#   'landed',
#   'in',
#   'guangzhou',
#   'for',
#   'a',
#   'rally',
#   '##ing',
#   'at',
#   'the',
#   'river',
#   '##cent',
#   '##re',
#   'join',
#   'me',
#   'at',
#   'pm',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'florida',
#   'can',
#   '##t',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'friday',
#   'in',
#   'miami',
#   'join',
#   'me',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'at',
#   '##f',
#   '##d',
#   'im',
#   '##with',
#   '##you',
#   'video',
#   '[SEP]'],
#  ['[CLS]',
#   'great',
#   'poll',
#   'florida',
#   'thank',
#   'you',
#   'im',
#   '##with',
#   '##you',
#   'america',
#   '##fi',
#   '##rst',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'ohio',
#   'see',
#   'you',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   '[SEP]'],
#  ['[CLS]',
#   'russia',
#   'took',
#   'crimea',
#   'during',
#   'the',
#   'soc',
#   '##alle',
#   '##d',
#   'barack',
#   '##bara',
#   '##cko',
#   '##ba',
#   '##ma',
#   'years',
#   'who',
#   'wouldn',
#   '##t',
#   'know',
#   'this',
#   'and',
#   'why',
#   'does',
#   'barack',
#   '##bara',
#   '##cko',
#   '##ba',
#   '##ma',
#   'get',
#   'a',
#   'free',
#   'pass',
#   '[SEP]'],
#  ['[CLS]',
#   'why',
#   'isn',
#   '##t',
#   'barack',
#   '##ob',
#   '##ama',
#   'working',
#   'instead',
#   'of',
#   'campaigning',
#   'for',
#   'hillary',
#   '##cl',
#   '##inton',
#   '[SEP]'],
#  ['[CLS]', 'thank', 'you', 'rep', 'cynthia', '##lum', '##mis', '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'rep',
#   'marsh',
#   '##ab',
#   '##la',
#   '##ck',
#   '##burn',
#   '[SEP]'],
#  ['[CLS]', 'thank', 'you', 'rep', '##ren', '##ee', '##ell', '##mers', '[SEP]'],
#  ['[CLS]',
#   'donald',
#   '##trum',
#   '##p',
#   'outlines',
#   'new',
#   'child',
#   '##care',
#   'policy',
#   'proposals',
#   'via',
#   'the',
#   'fox',
#   '##ne',
#   '##ws',
#   'app',
#   'real',
#   '##don',
#   '##ald',
#   '##don',
#   '##ald',
#   '##trum',
#   '##p',
#   'seems',
#   'a',
#   'candidate',
#   'of',
#   'destiny',
#   '[SEP]'],
#  ['[CLS]',
#   'child',
#   'care',
#   '##rel',
#   '##ie',
#   '##fa',
#   '##gen',
#   '##cy',
#   'reforms',
#   'that',
#   'will',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'transcript',
#   '[SEP]'],
#  ['[CLS]',
#   'ivan',
#   '##ka',
#   'penned',
#   'an',
#   'op',
#   '##ed',
#   'that',
#   'ran',
#   'in',
#   'the',
#   'the',
#   '##wall',
#   '##st',
#   '##ree',
#   '##t',
#   '##jou',
#   '##rna',
#   '##l',
#   'this',
#   'afternoon',
#   'read',
#   'it',
#   'here',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   '[SEP]'],
#  ['[CLS]', 'im', '##with', '##you', 'america', '##fi', '##rst', '[SEP]'],
#  ['[CLS]',
#   'ivan',
#   '##ka',
#   'is',
#   'joining',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'to',
#   'nutrition',
#   'an',
#   'innovative',
#   'new',
#   'domestic',
#   '##pol',
#   '##ic',
#   '##yo',
#   '##ft',
#   '##hes',
#   '##te',
#   '##ph',
#   '##en',
#   '##har',
#   '##per',
#   '##go',
#   '##vern',
#   '##ment',
#   'to',
#   'support',
#   'united',
#   '##sta',
#   '##tes',
#   'families',
#   'tune',
#   'in',
#   'to',
#   'watch',
#   'live',
#   'at',
#   'pm',
#   '[SEP]'],
#  ['[CLS]', 'thank', 'you', 'clive', '##io', '##wa', '[SEP]'],
#  ['[CLS]',
#   'join',
#   'us',
#   'the',
#   '##be',
#   '##ach',
#   '##boys',
#   '##to',
#   '##day',
#   'together',
#   'we',
#   'will',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'heading',
#   'to',
#   'iowa',
#   'join',
#   'me',
#   'today',
#   'at',
#   'noon',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'tickets',
#   '[SEP]'],
#  ['[CLS]',
#   'join',
#   'me',
#   'in',
#   'clive',
#   '##io',
#   '##wa',
#   'tomorrow',
#   'at',
#   'noon',
#   'america',
#   '##fi',
#   '##rst',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'tickets',
#   '[SEP]'],
#  ['[CLS]',
#   'br',
#   '##im',
#   '##yer',
#   '##s',
#   'saw',
#   'ur',
#   'speech',
#   'on',
#   'twitter',
#   'u',
#   'give',
#   'me',
#   'hope',
#   'and',
#   'optimism',
#   'i',
#   'feel',
#   'as',
#   'though',
#   'i',
#   'am',
#   'in',
#   'the',
#   'room',
#   'with',
#   'u',
#   'i',
#   'pray',
#   'ur',
#   '##our',
#   'success',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'got',
#   'back',
#   'from',
#   'north',
#   '##car',
#   '##olin',
#   '##a',
#   'north',
#   '##car',
#   '##olin',
#   '##a',
#   'where',
#   'we',
#   'had',
#   'a',
#   'massive',
#   'rally',
#   '##ing',
#   'spirit',
#   '##com',
#   '##ics',
#   '##cha',
#   '##rac',
#   '##ter',
#   'of',
#   'the',
#   'crowd',
#   'was',
#   'unbelievable',
#   'thank',
#   'you',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   '[SEP]'],
#  ['[CLS]',
#   'stopped',
#   'by',
#   'trump',
#   '##dc',
#   'to',
#   'thank',
#   'all',
#   'of',
#   'the',
#   'tremendous',
#   'men',
#   'women',
#   'for',
#   'their',
#   'hard',
#   'work',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'on',
#   'cn',
#   '##bc',
#   'at',
#   'enjoy',
#   '##re',
#   '##cor',
#   '##ds',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'will',
#   'be',
#   'interviewed',
#   'on',
#   'fox',
#   '##and',
#   '##fr',
#   '##ien',
#   '##ds',
#   'at',
#   'master',
#   '##of',
#   '##arts',
#   '[SEP]'],
#  ['[CLS]', 'never', '##for', '##get', '[SEP]'],
#  ['[CLS]',
#   'the',
#   'seriously',
#   'failing',
#   'then',
#   '##ew',
#   '##yo',
#   '##rk',
#   '##time',
#   '##s',
#   'despite',
#   'so',
#   'much',
#   'winning',
#   'and',
#   'poll',
#   'numbers',
#   'that',
#   'will',
#   'soon',
#   'put',
#   'me',
#   'in',
#   'first',
#   'place',
#   'only',
#   'writes',
#   'dish',
#   '##ones',
#   '##t',
#   'hits',
#   '##the',
#   '##very',
#   '##bes',
#   '##to',
#   '##fera',
#   '##sure',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'just',
#   'had',
#   'her',
#   'moment',
#   'what',
#   'a',
#   'terrible',
#   'thing',
#   'she',
#   'said',
#   'about',
#   'so',
#   'many',
#   'great',
#   'americans',
#   '[SEP]'],
#  ['[CLS]',
#   'rt',
#   '##tv',
#   '##net',
#   '##work',
#   'if',
#   'you',
#   'agree',
#   'we',
#   'need',
#   'a',
#   'president',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'who',
#   'is',
#   'fighting',
#   'for',
#   'all',
#   'americans',
#   'not',
#   'one',
#   'who',
#   'writes',
#   'off',
#   'nearly',
#   'half',
#   'the',
#   'country',
#   '[SEP]'],
#  ['[CLS]',
#   'while',
#   'hillary',
#   'said',
#   'horrible',
#   'things',
#   'about',
#   'my',
#   'supporters',
#   'and',
#   'while',
#   'many',
#   'of',
#   'her',
#   'supporters',
#   'will',
#   'never',
#   'vote',
#   'for',
#   'me',
#   'i',
#   'still',
#   'respect',
#   'them',
#   'all',
#   '[SEP]'],
#  ['[CLS]',
#   'really',
#   'sad',
#   'that',
#   'republican',
#   '##par',
#   '##ty',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'would',
#   'allow',
#   'themselves',
#   'to',
#   'be',
#   'used',
#   'in',
#   'a',
#   'hillary',
#   '##cl',
#   '##inton',
#   'ad',
#   'lindsey',
#   '##gra',
#   '##ham',
#   'mit',
#   '##trom',
#   '##ney',
#   'jeff',
#   '##fl',
#   '##ake',
#   'sas',
#   '##s',
#   'supreme',
#   'court',
#   'remember',
#   '[SEP]'],
#  ['[CLS]',
#   'wow',
#   '##ky',
#   '##lie',
#   '##min',
#   '##og',
#   '##ues',
#   '##ong',
#   'hillary',
#   '##cl',
#   '##inton',
#   'was',
#   'strike',
#   '##out',
#   'insulting',
#   'to',
#   'my',
#   'supporters',
#   'millions',
#   'of',
#   'amazing',
#   '##stor',
#   '##ies',
#   'hard',
#   'working',
#   'people',
#   'i',
#   'think',
#   'it',
#   'will',
#   'cost',
#   'her',
#   'at',
#   'the',
#   'polls',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'in',
#   'missouri',
#   'today',
#   'with',
#   'mel',
#   '##ania',
#   'for',
#   'the',
#   'funeral',
#   'of',
#   'a',
#   'wonderful',
#   'and',
#   'truly',
#   'respected',
#   'woman',
#   'phyllis',
#   's',
#   '[SEP]'],
#  ['[CLS]',
#   'st',
#   '##v',
#   '##z',
#   '##bn',
#   '##k',
#   'just',
#   'watched',
#   'tony',
#   '##sch',
#   '##wart',
#   '##z',
#   'obviously',
#   'tony',
#   'is',
#   'a',
#   'total',
#   'w',
#   '##ha',
#   '##ck',
#   'job',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'returned',
#   'from',
#   'naval',
#   '##air',
#   '##station',
#   '##pen',
#   '##sa',
#   '##cola',
#   'where',
#   'the',
#   'crowd',
#   'was',
#   'incredible',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'ha',
#   '##vn',
#   '##t',
#   'seen',
#   'tony',
#   '##sch',
#   '##wart',
#   '##z',
#   'in',
#   'many',
#   'years',
#   'he',
#   'hardly',
#   'knows',
#   'me',
#   'never',
#   'liked',
#   'his',
#   'style',
#   'super',
#   'li',
#   '##b',
#   'crooked',
#   'hydrogen',
#   'supporter',
#   'irrelevant',
#   'aircraft',
#   '##do',
#   '##pe',
#   '[SEP]'],
#  ['[CLS]',
#   'jockey',
#   '##sl',
#   '##ut',
#   'writer',
#   'tony',
#   '##sch',
#   '##wart',
#   '##z',
#   'who',
#   'wanted',
#   'to',
#   'do',
#   'a',
#   'second',
#   'book',
#   'with',
#   'me',
#   'for',
#   'years',
#   'i',
#   'said',
#   'no',
#   'is',
#   'now',
#   'a',
#   'hostile',
#   'basket',
#   '##case',
#   '##son',
#   '##g',
#   'who',
#   'feels',
#   'ji',
#   '##lt',
#   '##ed',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'florida',
#   'we',
#   'are',
#   'going',
#   'to',
#   'make',
#   '##ame',
#   '##rica',
#   '##gre',
#   '##ata',
#   '##gai',
#   '##n',
#   'join',
#   'us',
#   'america',
#   '##fi',
#   '##rst',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'be',
#   'delivering',
#   'a',
#   'major',
#   'speech',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'live',
#   'on',
#   'ore',
#   '##illy',
#   '##fa',
#   '##ctor',
#   'at',
#   'pm',
#   'from',
#   'naval',
#   '##air',
#   '##station',
#   '##pen',
#   '##sa',
#   '##cola',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'ohio',
# ...
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '##de',
#   '##mo',
#   '##cratic',
#   '##par',
#   '##ty',
#   'were',
#   'polled',
#   'other',
#   'polls',
#   'were',
#   'good',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'attacks',
#   'foreign',
#   'government',
#   'donations',
#   'while',
#   'ignoring',
#   'her',
#   'own',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'hillary',
#   '##cl',
#   '##inton',
#   'got',
#   'br',
#   '##ex',
#   '##it',
#   'wrong',
#   'i',
#   'said',
#   'leave',
#   'will',
#   'win',
#   'she',
#   'has',
#   'no',
#   'sense',
#   'of',
#   'markets',
#   'and',
#   'such',
#   'bad',
#   'judgement',
#   'only',
#   'a',
#   'question',
#   'of',
#   'time',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'is',
#   'not',
#   'a',
#   'change',
#   'agent',
#   'just',
#   'the',
#   'same',
#   'old',
#   'status',
#   '##qu',
#   '##o',
#   'she',
#   'is',
#   'spending',
#   'a',
#   'fortune',
#   'i',
#   'am',
#   'spending',
#   'very',
#   'little',
#   'close',
#   'in',
#   'polls',
#   '[SEP]'],
#  ['[CLS]',
#   'people',
#   'in',
#   'our',
#   'country',
#   'want',
#   'borders',
#   'and',
#   'without',
#   'them',
#   'the',
#   'old',
#   'line',
#   'pol',
#   '##s',
#   'like',
#   'crooked',
#   'hillary',
#   'will',
#   'not',
#   'win',
#   'it',
#   'is',
#   'time',
#   'for',
#   'change',
#   'and',
#   'jobs',
#   '[SEP]'],
#  ['[CLS]',
#   'top',
#   'facts',
#   'about',
#   'crooked',
#   'hillary',
#   'hillary',
#   '##cl',
#   '##inton',
#   'from',
#   'donald',
#   '##trum',
#   '##p',
#   'stakes',
#   'of',
#   'the',
#   'election',
#   'address',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'american',
#   '##bro',
#   '##ad',
#   '##cast',
#   '##ing',
#   '##com',
#   '##pan',
#   '##y',
#   'poll',
#   'sampling',
#   '##music',
#   'is',
#   'heavy',
#   'on',
#   'democratic',
#   '##par',
#   '##ty',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'very',
#   'dish',
#   '##ones',
#   '##t',
#   'why',
#   'would',
#   'they',
#   'do',
#   'that',
#   'other',
#   'polls',
#   'good',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'just',
#   'took',
#   'a',
#   'major',
#   'ad',
#   'of',
#   'me',
#   'playing',
#   'golf',
#   'at',
#   'turn',
#   '##berry',
#   '##castle',
#   'shows',
#   'me',
#   'hitting',
#   'shot',
#   'but',
#   'i',
#   'never',
#   'did',
#   'lie',
#   'was',
#   'there',
#   'to',
#   'support',
#   'son',
#   '[SEP]'],
#  ['[CLS]',
#   'clinton',
#   'is',
#   'trying',
#   'to',
#   'wash',
#   'away',
#   'her',
#   'bad',
#   'judgement',
#   'call',
#   'on',
#   'br',
#   '##ex',
#   '##it',
#   'with',
#   'big',
#   'united',
#   '##sta',
#   '##tes',
#   '##do',
#   '##llar',
#   'ads',
#   'disgrace',
#   '##ful',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'hillary',
#   '##cl',
#   '##inton',
#   'who',
#   'called',
#   'br',
#   '##ex',
#   '##it',
#   'wrong',
#   'along',
#   'with',
#   'barack',
#   '##ob',
#   '##ama',
#   'is',
#   'now',
#   'spending',
#   'wall',
#   'street',
#   'money',
#   'on',
#   'an',
#   'ad',
#   'on',
#   'my',
#   'correct',
#   'call',
#   '[SEP]'],
#  ['[CLS]',
#   'george',
#   '##wil',
#   '##l',
#   'one',
#   'of',
#   'the',
#   'most',
#   'over',
#   '##rated',
#   'political',
#   'pun',
#   '##dit',
#   '##s',
#   'who',
#   'lost',
#   'his',
#   'way',
#   'long',
#   'ago',
#   'has',
#   'left',
#   'the',
#   'republican',
#   '##par',
#   '##ty',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'party',
#   '##hes',
#   'made',
#   'many',
#   'bad',
#   'calls',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'landed',
#   'in',
#   'new',
#   '##yo',
#   '##rk',
#   '##city',
#   'a',
#   'one',
#   'night',
#   'stay',
#   'in',
#   'scotland',
#   'turn',
#   '##berry',
#   '##castle',
#   'came',
#   'out',
#   'magnificent',
#   '##ly',
#   'ms',
#   '##n',
#   'eric',
#   'did',
#   'a',
#   'great',
#   'job',
#   'under',
#   'budget',
#   '[SEP]'],
#  ['[CLS]',
#   'barack',
#   '##ob',
#   '##ama',
#   'has',
#   'blocked',
#   'us',
#   '##im',
#   '##mi',
#   '##gration',
#   '##and',
#   '##cus',
#   '##tom',
#   '##sen',
#   '##force',
#   '##ment',
#   'officers',
#   'and',
#   'bp',
#   'from',
#   'doing',
#   'their',
#   'jobs',
#   'that',
#   'ends',
#   'when',
#   'i',
#   'am',
#   'president',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'have',
#   'never',
#   'liked',
#   'the',
#   'media',
#   'term',
#   'deportation',
#   'but',
#   'we',
#   'must',
#   'enforce',
#   'the',
#   'laws',
#   'of',
#   'the',
#   'land',
#   '[SEP]'],
#  ['[CLS]',
#   'we',
#   'only',
#   'want',
#   'to',
#   'admit',
#   'those',
#   'who',
#   'love',
#   'our',
#   'people',
#   'and',
#   'support',
#   'our',
#   'values',
#   'america',
#   '##fi',
#   '##rst',
#   '[SEP]'],
#  ['[CLS]',
#   'we',
#   'must',
#   'suspend',
#   'immigration',
#   'from',
#   'regions',
#   'linked',
#   'with',
#   'terrorism',
#   'until',
#   'a',
#   'proven',
#   'vet',
#   '##ting',
#   'method',
#   'is',
#   'in',
#   'place',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'to',
#   'everyone',
#   'who',
#   'came',
#   'out',
#   'joined',
#   'us',
#   'trump',
#   '##turn',
#   '##berry',
#   'yesterday',
#   'eric',
#   '##trum',
#   '##p',
#   'ivan',
#   '##kat',
#   '##rum',
#   '##p',
#   'donald',
#   '##j',
#   '##trum',
#   '##p',
#   '##j',
#   '##r',
#   '[SEP]'],
#  ['[CLS]',
#   'on',
#   'the',
#   'th',
#   'tee',
#   '##ing',
#   '##ground',
#   'trump',
#   '##sco',
#   '##tland',
#   'with',
#   'my',
#   'grand',
#   'daughter',
#   'kai',
#   '##pro',
#   '##vin',
#   '##ce',
#   'donald',
#   '##j',
#   '##trum',
#   '##p',
#   '##j',
#   '##r',
#   '[SEP]'],
#  ['[CLS]',
#   'arriving',
#   'trump',
#   '##sco',
#   '##tland',
#   'with',
#   'donald',
#   '##j',
#   '##trum',
#   '##p',
#   '##j',
#   '##r',
#   'eric',
#   '##trum',
#   '##p',
#   'back',
#   'to',
#   'new',
#   '##yo',
#   '##rk',
#   '##city',
#   'the',
#   '##ton',
#   '##ight',
#   '##sho',
#   '##w',
#   'video',
#   '[SEP]'],
#  ['[CLS]',
#   'so',
#   'funny',
#   'crooked',
#   'hillary',
#   'called',
#   'br',
#   '##ex',
#   '##it',
#   'so',
#   'incorrectly',
#   'and',
#   'now',
#   'she',
#   'says',
#   'that',
#   'she',
#   'is',
#   'the',
#   'one',
#   'to',
#   'deal',
#   'with',
#   'the',
#   'united',
#   '##king',
#   '##dom',
#   'all',
#   'talk',
#   'no',
#   'action',
#   '##pro',
#   '##gram',
#   '##ming',
#   '##lang',
#   '##ua',
#   '##ge',
#   '[SEP]'],
#  ['[CLS]',
#   'thoughts',
#   'and',
#   'prayers',
#   'are',
#   'with',
#   'everyone',
#   'in',
#   'west',
#   '##vir',
#   '##gin',
#   '##ia',
#   'dealing',
#   'with',
#   'the',
#   'devastating',
#   'floods',
#   'im',
#   '##with',
#   '##you',
#   '[SEP]'],
#  ['[CLS]',
#   'jo',
#   '##lena',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'and',
#   'we',
#   'will',
#   'get',
#   'it',
#   'back',
#   'once',
#   'we',
#   'have',
#   'donald',
#   '##trum',
#   '##p',
#   'can',
#   '##t',
#   '##wai',
#   '##t',
#   '[SEP]'],
#  ['[CLS]',
#   'darren',
#   '##wa',
#   '##gg',
#   '##ener',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'what',
#   'has',
#   'happened',
#   'in',
#   'the',
#   'united',
#   '##king',
#   '##dom',
#   'in',
#   'the',
#   'last',
#   'hours',
#   'is',
#   'exactly',
#   'what',
#   'will',
#   'happen',
#   'in',
#   'november',
#   '##vot',
#   '##e',
#   'donald',
#   '##trum',
#   '##pp',
#   '##res',
#   '##ide',
#   '##ntial',
#   '##camp',
#   '##ai',
#   '##gn',
#   '[SEP]'],
#  ['[CLS]',
#   'many',
#   'people',
#   'are',
#   'e',
#   '##qua',
#   '##ting',
#   'br',
#   '##ex',
#   '##it',
#   'and',
#   'what',
#   'is',
#   'going',
#   'on',
#   'in',
#   'great',
#   '##bri',
#   '##tain',
#   'with',
#   'what',
#   'is',
#   'happening',
#   'in',
#   'the',
#   'united',
#   '##sta',
#   '##tes',
#   'people',
#   'want',
#   'their',
#   'country',
#   'back',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'opening',
#   'of',
#   'turn',
#   '##berry',
#   '##gol',
#   '##fc',
#   '##ours',
#   '##e',
#   'in',
#   'scotland',
#   'was',
#   'a',
#   'big',
#   'success',
#   'good',
#   '##ti',
#   '##ming',
#   'i',
#   'was',
#   'here',
#   'for',
#   'br',
#   '##ex',
#   '##it',
#   'very',
#   'exciting',
#   'news',
#   '##con',
#   '##ference',
#   'the',
#   '##be',
#   '##ach',
#   '##boys',
#   '##to',
#   '##day',
#   '[SEP]'],
#  ['[CLS]',
#   'crooked',
#   'hillary',
#   'called',
#   'it',
#   'totally',
#   'wrong',
#   'on',
#   'br',
#   '##ex',
#   '##it',
#   'she',
#   'went',
#   'with',
#   'barack',
#   '##ob',
#   '##ama',
#   'and',
#   'now',
#   'she',
#   'is',
#   'saying',
#   'we',
#   'need',
#   'her',
#   'to',
#   'lead',
#   'she',
#   'would',
#   'be',
#   'a',
#   'disaster',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'want',
#   'all',
#   'americans',
#   'to',
#   'succeed',
#   'together',
#   'barack',
#   '##ob',
#   '##ama',
#   '##s',
#   'illegal',
#   'executive',
#   'amnesty',
#   'undermine',
#   '##s',
#   'job',
#   'prospects',
#   'for',
#   '[SEP]'],
#  ['[CLS]',
#   'new',
#   'government',
#   'data',
#   'by',
#   'the',
#   'center',
#   'for',
#   'immigration',
#   'studies',
#   'shows',
#   'more',
#   'than',
#   'm',
#   'new',
#   'legal',
#   'illegal',
#   '##im',
#   '##mi',
#   '##gration',
#   'settled',
#   '[SEP]'],
#  ['[CLS]',
#   'united',
#   '##sta',
#   '##tes',
#   'is',
#   'proud',
#   'to',
#   'stand',
#   'shoulder',
#   '##tos',
#   '##ho',
#   '##uld',
#   '##er',
#   'wa',
#   'free',
#   'independents',
#   '##ub',
#   '##ways',
#   '##yst',
#   '##em',
#   'united',
#   '##king',
#   '##dom',
#   'we',
#   'stand',
#   'together',
#   'as',
#   'friends',
#   'as',
#   'allies',
#   'as',
#   'a',
#   'people',
#   'wa',
#   'shared',
#   'history',
#   '[SEP]'],
#  ['[CLS]',
#   'self',
#   '##de',
#   '##ter',
#   '##mina',
#   '##tion',
#   'is',
#   'the',
#   'sacred',
#   'right',
#   'of',
#   'all',
#   'free',
#   'peoples',
#   'and',
#   'the',
#   'people',
#   'of',
#   'the',
#   'united',
#   '##king',
#   '##dom',
#   'have',
#   'exercised',
#   'that',
#   'right',
#   'for',
#   'all',
#   'the',
#   'world',
#   'to',
#   'see',
#   '[SEP]'],
#  ['[CLS]',
#   'getting',
#   'ready',
#   'to',
#   'open',
#   'the',
#   'magnificent',
#   'turn',
#   '##berry',
#   '##castle',
#   'in',
#   'scotland',
#   'what',
#   'a',
#   'great',
#   'day',
#   'especially',
#   'when',
#   'added',
#   'to',
#   'the',
#   'brave',
#   'brilliant',
#   'vote',
#   '[SEP]'],
#  ['[CLS]',
#   'statement',
#   'regarding',
#   'united',
#   '##king',
#   '##dome',
#   '##uro',
#   '##pe',
#   '##anu',
#   '##nio',
#   '##n',
#   '##me',
#   '##mber',
#   '##ship',
#   '##re',
#   '##fer',
#   '##end',
#   '##um',
#   'on',
#   'european',
#   '##uni',
#   '##on',
#   'membership',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'arrived',
#   'in',
#   'scotland',
#   'place',
#   'is',
#   'going',
#   'wild',
#   'over',
#   'the',
#   'vote',
#   'they',
#   'took',
#   'their',
#   'country',
#   'back',
#   'just',
#   'like',
#   'we',
#   'will',
#   'take',
#   'united',
#   '##sta',
#   '##tes',
#   'back',
#   'no',
#   'games',
#   '[SEP]'],
#  ['[CLS]',
#   'traveling',
#   '##wil',
#   '##bury',
#   '##s',
#   '##vo',
#   '##l',
#   'to',
#   'my',
#   'son',
#   'eric',
#   'on',
#   'the',
#   'fantastic',
#   'job',
#   'he',
#   'has',
#   'done',
#   'in',
#   'rebuilding',
#   'turn',
#   '##berry',
#   '##castle',
#   'and',
#   'its',
#   'great',
#   'ai',
#   '##ls',
#   '##ast',
#   '##ew',
#   '##art',
#   'course',
#   'always',
#   'support',
#   'kids',
#   '[SEP]'],
#  ['[CLS]',
#   'leaving',
#   'now',
#   'for',
#   'a',
#   'one',
#   'night',
#   'trip',
#   'to',
#   'scotland',
#   'in',
#   'order',
#   'to',
#   'be',
#   'at',
#   'the',
#   'grand',
#   'opening',
#   'of',
#   'my',
#   'great',
#   'turn',
#   '##berry',
#   '##gol',
#   '##fc',
#   '##ours',
#   '##e',
#   'will',
#   'be',
#   'back',
#   'on',
#   'sat',
#   'night',
#   '[SEP]'],
#  ['[CLS]',
#   'meet',
#   'the',
#   'amazing',
#   '##stor',
#   '##ies',
#   'mother',
#   'whose',
#   'letter',
#   'i',
#   'read',
#   'during',
#   'my',
#   'speech',
#   'she',
#   'lost',
#   'her',
#   'son',
#   'to',
#   'policies',
#   'supported',
#   'by',
#   'bill',
#   '##cl',
#   '##inton',
#   '[SEP]'],
#  ['[CLS]',
#   'read',
#   'my',
#   'full',
#   'statement',
#   'here',
#   'on',
#   'the',
#   'supreme',
#   '##court',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '##s',
#   'executive',
#   'amnesty',
#   'decision',
#   'im',
#   '##with',
#   '##you',
#   '[SEP]'],
#  ['[CLS]',
#   'here',
#   'is',
#   'another',
#   'cnn',
#   'lie',
#   'the',
#   'clinton',
#   'news',
#   'network',
#   'is',
#   'losing',
#   'all',
#   'credibility',
#   'i',
#   '’',
#   'm',
#   'not',
#   'watching',
#   'it',
#   'much',
#   'anymore',
#   '[SEP]'],
#  ['[CLS]',
#   'cnn',
#   'which',
#   'is',
#   'totally',
#   '##bia',
#   '##sed',
#   '##with',
#   '##wk',
#   '##ama',
#   '##ub',
#   '##ell',
#   'in',
#   'favor',
#   'of',
#   'hillary',
#   '##cl',
#   '##inton',
#   'should',
#   'apologize',
#   'they',
#   'knew',
#   'they',
#   'were',
#   'wrong',
#   '[SEP]'],
#  ['[CLS]',
#   'donald',
#   '##don',
#   '##ald',
#   '##trum',
#   '##ps',
#   'speech',
#   'today',
#   'is',
#   'the',
#   'best',
#   'persuasion',
#   'i',
#   'have',
#   'ever',
#   'seen',
#   'game',
#   'over',
#   'now',
#   'running',
#   'unopposed',
#   'donald',
#   '##don',
#   '##ald',
#   '##trum',
#   '##p',
#   'clinton',
#   '[SEP]'],
#  ['[CLS]',
#   'our',
#   'inner',
#   'cities',
#   'have',
#   'been',
#   'left',
#   'behind',
#   'we',
#   'will',
#   'never',
#   'have',
#   'the',
#   'resources',
#   'to',
#   'support',
#   'our',
#   'people',
#   'if',
#   'we',
#   'have',
#   'an',
#   'open',
#   '##bor',
#   '##der',
#   '[SEP]'],
#  ['[CLS]',
#   'on',
#   'immigration',
#   'i',
#   '’',
#   'm',
#   'consulting',
#   'with',
#   'our',
#   'immigration',
#   'officers',
#   'our',
#   'wage',
#   '##ear',
#   '##ners',
#   'hillary',
#   '##cl',
#   '##inton',
#   'is',
#   'consulting',
#   'with',
#   'wall',
#   'street',
#   '[SEP]'],
#  ['[CLS]',
#   'barack',
#   '##ob',
#   '##ama',
#   'bill',
#   '##cl',
#   '##inton',
#   'should',
#   'stop',
#   'meeting',
#   'with',
#   'advocacy',
#   '##group',
#   'start',
#   'meeting',
#   'with',
#   'the',
#   'victims',
#   'of',
#   'illegal',
#   '##im',
#   '##mi',
#   '##gration',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   '’',
#   's',
#   'open',
#   '##bor',
#   '##der',
#   'are',
#   'tearing',
#   'united',
#   '##sta',
#   '##tes',
#   'families',
#   'apart',
#   'i',
#   'am',
#   'going',
#   'to',
#   'make',
#   'our',
#   'country',
#   'safe',
#   'again',
#   'for',
#   'all',
#   'united',
#   '##sta',
#   '##tes',
#   '##s',
#   'im',
#   '##with',
#   '##you',
#   '[SEP]'],
#  ['[CLS]',
#   'south',
#   '##car',
#   '##olin',
#   '##a',
#   'has',
#   'kept',
#   'us',
#   'safe',
#   'from',
#   'ex',
#   '##ec',
#   '##sy',
#   '##ste',
#   '##mc',
#   '##all',
#   'amnesty',
#   '##for',
#   'now',
#   'but',
#   'hillary',
#   'has',
#   'pledged',
#   'to',
#   'expand',
#   'it',
#   'taking',
#   'jobs',
#   'from',
#   'race',
#   '##and',
#   '##eth',
#   '##nic',
#   '##ity',
#   '##int',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   '##cens',
#   '##us',
#   'african',
#   '##ame',
#   '##rica',
#   '##ns',
#   'workers',
#   '[SEP]'],
#  ['[CLS]',
#   'jerry',
#   '##j',
#   '##rf',
#   '##al',
#   '##well',
#   'i',
#   'was',
#   'so',
#   'impressed',
#   'by',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   '##s',
#   'speech',
#   'yesterday',
#   'he',
#   'was',
#   'the',
#   'best',
#   'iv',
#   '##e',
#   'ever',
#   'seen',
#   'him',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   'lies',
#   'to',
#   'ben',
#   '##gh',
#   '##azi',
#   'families',
#   'crooked',
#   '##hill',
#   '##ary',
#   '[SEP]'],
#  ['[CLS]',
#   'islamic',
#   '##sta',
#   '##te',
#   '##of',
#   '##ira',
#   '##qa',
#   '##ndt',
#   '##hel',
#   '##eva',
#   '##nt',
#   'threatens',
#   'us',
#   'today',
#   'because',
#   'of',
#   'the',
#   'decisions',
#   'hillary',
#   '##cl',
#   '##inton',
#   'has',
#   'made',
#   'along',
#   'with',
#   'barack',
#   '##ob',
#   '##ama',
#   'donald',
#   'j',
#   'donald',
#   '##trum',
#   '##p',
#   '[SEP]'],
#  ['[CLS]',
#   'hillary',
#   '##cl',
#   '##inton',
#   'may',
#   'be',
#   'the',
#   'most',
#   'corrupt',
#   'person',
#   'ever',
#   'to',
#   'seek',
#   'the',
#   'presidency',
#   'donald',
#   'j',
#   'donald',
#   '##trum',
#   '##p',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'to',
#   'donald',
#   '##rum',
#   '##sf',
#   '##eld',
#   'for',
#   'the',
#   'endorsement',
#   'very',
#   'much',
#   'appreciated',
#   'hillary',
#   '##cl',
#   '##inton',
#   '##s',
#   'conduct',
#   'has',
#   'been',
#   'di',
#   '##s',
#   '##qual',
#   '##ifying',
#   '[SEP]'],
#  ['[CLS]',
#   'all',
#   '##eg',
#   '##ret',
#   '##tiv',
#   '##ick',
#   '##i',
#   'you',
#   'have',
#   'great',
#   'children',
#   'future',
#   'presidents',
#   '##and',
#   'we',
#   'all',
#   'see',
#   'were',
#   'raised',
#   'right',
#   'and',
#   'out',
#   'there',
#   'for',
#   'their',
#   'father',
#   'thank',
#   'you',
#   '[SEP]'],
#  ['[CLS]',
#   'lion',
#   'brilliant',
#   'word',
#   'response',
#   'to',
#   'hillary',
#   '##s',
#   'im',
#   '##with',
#   '##you',
#   '##av',
#   '##rill',
#   '##avi',
#   '##gne',
#   '##son',
#   '##g',
#   'slogan',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   '[SEP]'],
#  ['[CLS]',
#   'justin',
#   '##ing',
#   '##l',
#   '##v',
#   'donald',
#   '##trum',
#   '##pon',
#   '##so',
#   '##cial',
#   '##media',
#   'great',
#   'speech',
#   'the',
#   '##be',
#   '##ach',
#   '##boys',
#   '##to',
#   '##day',
#   'its',
#   'all',
#   'about',
#   'united',
#   '##sta',
#   '##tes',
#   'and',
#   'that',
#   '##s',
#   'why',
#   'you',
#   'will',
#   'become',
#   'president',
#   '##oft',
#   '##he',
#   '##uni',
#   '##ted',
#   '##sta',
#   '##tes',
#   'thank',
#   'you',
#   '[SEP]'],
#  ...]
