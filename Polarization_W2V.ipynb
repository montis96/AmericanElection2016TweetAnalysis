# %% [markdown]
# # Import libraries

# %%
# !pip install emoji
# !pip install gensim
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.6/dist-packages (1.2.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (4.1.2)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.19.5)

# %%
from google.colab import drive

import pandas as pd
import os
import string
import numpy as np

## Preprocessing
import emoji
import re
import html
import nltk
import regex
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize.casual import TweetTokenizer
from collections import Counter #token counter

# W2v
from gensim.models import Word2Vec

#Cosine
from scipy.spatial.distance import cosine

# %% [markdown]
# # Load dataset

# %%
drive.mount('/content/drive', force_remount = True)
root_dir = '/content/drive/MyDrive/ProgettoAI/dataset/'

trump = pd.read_csv(root_dir+'tweet_with_entities_trump.csv', index_col=0  ).rename(columns={'tweet' : 'text'})
clinton = pd.read_csv(root_dir+'tweet_with_entities_clinton.csv', index_col=0  ).rename(columns={'tweet' : 'text'})
# Out:
# Mounted at /content/drive

# %%
trump['text'].iloc[0]
# Out:
# 'Join me for a 3pm Rallying - tomorrow at the MidAmericaCenter in RailsWestRailroadMuseum! Tickets:… https://t.co/dfzsbICiXc'

# %% [markdown]
# # Preprocessing

# %%
START_OF_LINE = r"^"
OPTIONAL = "?"
ANYTHING = "."
ZERO_OR_MORE = "*"
ONE_OR_MORE = "+"

SPACE = "\s"
SPACES = SPACE + ONE_OR_MORE
NOT_SPACE = "[^\s]" + ONE_OR_MORE
EVERYTHING_OR_NOTHING = ANYTHING + ZERO_OR_MORE

ERASE = ""
FORWARD_SLASH = "\/"
NEWLINES = r"[\r\n]"

RE_TWEET = START_OF_LINE + "RT" + SPACES

HYPERLINKS = ("http" + "s" + OPTIONAL + ":" + FORWARD_SLASH + FORWARD_SLASH
              + NOT_SPACE + NEWLINES + ZERO_OR_MORE)

HASH = "#"
TAG = "@"

def cleaning_up(tweets):
    print("CLEANING...")
    clean =[]
    
    for tweet in tweets['text']:

        tweet = html.unescape(html.unescape(tweet)) #caratteri html
        tweet = re.sub(RE_TWEET, ERASE, tweet)  #re:
        tweet = re.sub(HYPERLINKS, ERASE, tweet) #url
        tweet = re.sub(HASH, ERASE, tweet) #hash simbolo
        tweet = re.sub(TAG, ERASE, tweet) #delete @
        #tweet = re.sub("@[^\s]+",ERASE,tweet) #tag username
        tweet = re.sub('<.*?>', ERASE, tweet) #tag html
        tweet = emoji.demojize(tweet) #traduzione delle emoji
        tweet = re.sub(r":", ' ', tweet) #serve per le emoji
        tweet = re.sub(r'\d+', '', tweet) #number
        tweet = tweet.translate(str.maketrans('', '', string.punctuation) )
    
        clean.append(tweet)
      
    print("---CLEANED---")

    return clean

def get_wordnet_pos(tag):
    if tag[1].startswith('J'):
        return wordnet.ADJ
    elif tag[1].startswith('S'):
        return wordnet.ADJ_SAT
    elif tag[1].startswith('V'):
        return wordnet.VERB
    elif tag[1].startswith('N'):
        return wordnet.NOUN
    elif tag[1].startswith('R'):
        return wordnet.ADV
    else:
        return ''

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

def tweet_tokenize(tweets):
    
    print("TOKENIZATION...")
    all_tokens=[]
    tokens =[] 
    tokenizer = word_tokenize

    for tweet in tweets:
        temp=[]
        all_tokens = tokenizer(tweet)
        lemmatizer = WordNetLemmatizer()
        stop_words = stopwords.words('english')
        for token in all_tokens:
                token = token.lower()
                if not (
                    not token.isalpha()
                    or token in stop_words 
                    or token in string.punctuation
                    or (token.isalpha() and len(token) < 2)):
                        tagged = nltk.pos_tag([token])
                        parsed = get_wordnet_pos(tagged[0])
                        #if parsed != '':
                         #   token = lemmatizer.lemmatize(token, parsed)
                        temp.append(token)
        tokens.append(temp) 

    print("---TOKENIZED---")

    return tokens

def get_word_frequencies(corpus):
  frequencies = Counter()
  for sentence in corpus:
    for word in sentence:
      frequencies[word] += 1
  freq = frequencies.most_common()
  return freq
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
trump_cleaned = cleaning_up(trump)
trump_tokens = tweet_tokenize(trump_cleaned)

clinton_cleaned = cleaning_up(clinton)
clinton_tokens = tweet_tokenize(clinton_cleaned)
# Out:
# CLEANING...
# ---CLEANED---
# TOKENIZATION...
# ---TOKENIZED---
# CLEANING...
# ---CLEANED---
# TOKENIZATION...
# ---TOKENIZED---

# %%
get_word_frequencies(trump_tokens)
# Out:
# [('thank', 517),
#  ('makeamericagreatagain', 394),
#  ('trump', 380),
#  ('great', 346),
#  ('donaldtrump', 276),
#  ('donaldtrumponsocialmedia', 272),
#  ('hillary', 262),
#  ('people', 219),
#  ('unitedstates', 198),
#  ('crooked', 182),
#  ('hillaryclinton', 174),
#  ('get', 132),
#  ('vote', 120),
#  ('big', 117),
#  ('like', 114),
#  ('presidentoftheunitedstates', 112),
#  ('would', 109),
#  ('thetonightshow', 109),
#  ('cnn', 106),
#  ('many', 106),
#  ('join', 104),
#  ('tedcruz', 101),
#  ('pm', 100),
#  ('one', 99),
#  ('jervycruz', 98),
#  ('poll', 97),
#  ('foxnews', 97),
#  ('last', 89),
#  ('enjoyrecords', 88),
#  ('never', 87),
#  ('new', 87),
#  ('going', 82),
#  ('back', 82),
#  ('today', 80),
#  ('said', 80),
#  ('make', 79),
#  ('country', 78),
#  ('speech', 78),
#  ('time', 76),
#  ('media', 76),
#  ('much', 73),
#  ('marcorubio', 72),
#  ('win', 71),
#  ('iowa', 70),
#  ('see', 69),
#  ('want', 69),
#  ('votetrump', 69),
#  ('support', 67),
#  ('watch', 66),
#  ('job', 65),
#  ('americafirst', 64),
#  ('jobs', 64),
#  ('bad', 64),
#  ('interviewed', 64),
#  ('us', 61),
#  ('love', 61),
#  ('show', 61),
#  ('campaign', 60),
#  ('night', 60),
#  ('way', 60),
#  ('good', 60),
#  ('dont', 59),
#  ('barackobama', 59),
#  ('tomorrow', 58),
#  ('imwithyou', 58),
#  ('even', 58),
#  ('amazingstories', 57),
#  ('crowd', 57),
#  ('ohio', 56),
#  ('soon', 55),
#  ('megynkelly', 54),
#  ('debate', 53),
#  ('really', 53),
#  ('go', 53),
#  ('republicanpartyunitedstates', 53),
#  ('wowkylieminoguesong', 51),
#  ('thenewyorktimes', 51),
#  ('dishonest', 51),
#  ('polls', 50),
#  ('unitedstatessenate', 50),
#  ('totally', 50),
#  ('newhampshire', 49),
#  ('ted', 49),
#  ('failing', 48),
#  ('got', 48),
#  ('years', 46),
#  ('says', 45),
#  ('made', 45),
#  ('total', 45),
#  ('beat', 45),
#  ('donalddonaldtrumponsocialmedia', 45),
#  ('florida', 44),
#  ('say', 43),
#  ('berniesanders', 43),
#  ('cant', 43),
#  ('rallying', 42),
#  ('day', 42),
#  ('done', 42),
#  ('ever', 42),
#  ('video', 42),
#  ('southcarolina', 42),
#  ('islamicstateofiraqandthelevant', 41),
#  ('wants', 41),
#  ('must', 41),
#  ('state', 41),
#  ('another', 41),
#  ('morning', 41),
#  ('nice', 40),
#  ('supporters', 40),
#  ('newyorkcity', 40),
#  ('yousouthafricanmagazine', 40),
#  ('run', 40),
#  ('endorsement', 39),
#  ('nothing', 39),
#  ('candidate', 39),
#  ('wonderful', 39),
#  ('women', 39),
#  ('know', 39),
#  ('believe', 39),
#  ('everyone', 38),
#  ('lyin', 38),
#  ('indiana', 38),
#  ('sad', 37),
#  ('money', 37),
#  ('right', 36),
#  ('million', 36),
#  ('take', 36),
#  ('bernie', 36),
#  ('foxandfriends', 35),
#  ('failed', 35),
#  ('forward', 34),
#  ('watching', 34),
#  ('ratings', 34),
#  ('better', 34),
#  ('well', 33),
#  ('together', 33),
#  ('looking', 33),
#  ('two', 33),
#  ('didnt', 33),
#  ('record', 33),
#  ('ads', 33),
#  ('jebbush', 33),
#  ('tickets', 32),
#  ('america', 32),
#  ('trumptrain', 32),
#  ('think', 32),
#  ('donalddonaldtrump', 32),
#  ('movement', 31),
#  ('little', 31),
#  ('keep', 31),
#  ('massive', 31),
#  ('doesnt', 31),
#  ('voters', 31),
#  ('deal', 31),
#  ('stop', 31),
#  ('wall', 31),
#  ('story', 31),
#  ('interview', 31),
#  ('lost', 30),
#  ('look', 30),
#  ('pennsylvania', 30),
#  ('ad', 30),
#  ('phony', 30),
#  ('votes', 29),
#  ('put', 29),
#  ('oreillyfactor', 29),
#  ('weak', 29),
#  ('millions', 29),
#  ('wisconsin', 29),
#  ('honor', 28),
#  ('getting', 28),
#  ('thanks', 28),
#  ('trumppence', 28),
#  ('seanhannity', 28),
#  ('need', 28),
#  ('remember', 28),
#  ('best', 28),
#  ('mittromney', 28),
#  ('lightweight', 28),
#  ('far', 28),
#  ('primary', 28),
#  ('kasich', 28),
#  ('change', 27),
#  ('shows', 27),
#  ('virginia', 27),
#  ('nevada', 27),
#  ('terrorism', 27),
#  ('let', 27),
#  ('person', 27),
#  ('saying', 26),
#  ('numbers', 26),
#  ('emails', 26),
#  ('rigged', 26),
#  ('proud', 26),
#  ('things', 26),
#  ('texas', 26),
#  ('yet', 26),
#  ('im', 26),
#  ('arizona', 26),
#  ('jeb', 26),
#  ('fitn', 26),
#  ('false', 25),
#  ('first', 25),
#  ('via', 25),
#  ('safe', 25),
#  ('billclinton', 25),
#  ('meeting', 25),
#  ('historyoftheunitedstatesrepublicanparty', 25),
#  ('others', 25),
#  ('negative', 25),
#  ('goofy', 25),
#  ('true', 24),
#  ('bring', 24),
#  ('masterofarts', 24),
#  ('gave', 24),
#  ('badly', 24),
#  ('hard', 24),
#  ('lies', 24),
#  ('elizabethwarren', 24),
#  ('delegates', 24),
#  ('gopdebate', 24),
#  ('talk', 23),
#  ('judgement', 23),
#  ('leaving', 23),
#  ('strong', 23),
#  ('fantastic', 23),
#  ('wont', 23),
#  ('yesterday', 23),
#  ('twitter', 22),
#  ('every', 22),
#  ('watched', 22),
#  ('world', 22),
#  ('system', 22),
#  ('trade', 22),
#  ('tough', 22),
#  ('work', 22),
#  ('come', 22),
#  ('man', 22),
#  ('also', 22),
#  ('could', 22),
#  ('spent', 22),
#  ('smart', 22),
#  ('foxbroadcastingcompany', 22),
#  ('national', 21),
#  ('mikepence', 21),
#  ('special', 21),
#  ('fight', 21),
#  ('lookamericanmagazine', 21),
#  ('colorado', 21),
#  ('event', 21),
#  ('pme', 21),
#  ('mexico', 21),
#  ('crookedhillary', 21),
#  ('guy', 21),
#  ('supertuesday', 21),
#  ('thebeachboystoday', 20),
#  ('governor', 20),
#  ('spending', 20),
#  ('evening', 20),
#  ('always', 20),
#  ('making', 20),
#  ('endorsed', 20),
#  ('morningjoe', 20),
#  ('hit', 20),
#  ('mr', 20),
#  ('press', 20),
#  ('words', 20),
#  ('politicians', 20),
#  ('iacaucus', 20),
#  ('hillarys', 19),
#  ('away', 19),
#  ('killed', 19),
#  ('immigration', 19),
#  ('northcarolina', 19),
#  ('major', 19),
#  ('disaster', 19),
#  ('next', 19),
#  ('canada', 19),
#  ('nobody', 19),
#  ('wrong', 19),
#  ('debates', 18),
#  ('americans', 18),
#  ('fact', 18),
#  ('dumb', 18),
#  ('coming', 18),
#  ('worse', 18),
#  ('officers', 18),
#  ('statement', 18),
#  ('working', 18),
#  ('joke', 18),
#  ('real', 18),
#  ('called', 18),
#  ('defensivelyequippedmerchantship', 18),
#  ('candidates', 18),
#  ('tuesday', 18),
#  ('television', 18),
#  ('worst', 18),
#  ('caucus', 18),
#  ('call', 17),
#  ('logicalconjunction', 17),
#  ('voted', 17),
#  ('tremendous', 17),
#  ('th', 17),
#  ('ivankatrump', 17),
#  ('leadership', 17),
#  ('heading', 17),
#  ('anything', 17),
#  ('live', 17),
#  ('used', 17),
#  ('please', 17),
#  ('close', 17),
#  ('voting', 17),
#  ('since', 17),
#  ('looks', 17),
#  ('fraud', 17),
#  ('andersoncooper', 17),
#  ('hillaryclintons', 16),
#  ('still', 16),
#  ('thewallstreetjournal', 16),
#  ('lets', 16),
#  ('allowed', 16),
#  ('truly', 16),
#  ('amazing', 16),
#  ('told', 16),
#  ('home', 16),
#  ('knows', 16),
#  ('read', 16),
#  ('place', 16),
#  ('woman', 16),
#  ('almost', 16),
#  ('patientprotectionandaffordablecareact', 16),
#  ('left', 16),
#  ('help', 16),
#  ('erictrump', 16),
#  ('report', 16),
#  ('gretathunberg', 16),
#  ('history', 16),
#  ('wife', 16),
#  ('raceandethnicityintheunitedstatescensus', 15),
#  ('four', 15),
#  ('winning', 15),
#  ('victory', 15),
#  ('thats', 15),
#  ('police', 15),
#  ('election', 15),
#  ('economy', 15),
#  ('news', 15),
#  ('low', 15),
#  ('incredible', 15),
#  ('email', 15),
#  ('veterans', 15),
#  ('fix', 15),
#  ('biased', 15),
#  ('pay', 15),
#  ('michigan', 15),
#  ('racing', 15),
#  ('running', 15),
#  ('went', 15),
#  ('happy', 15),
#  ('rncincle', 15),
#  ('travelingwilburysvol', 15),
#  ('iran', 14),
#  ('families', 14),
#  ('politician', 14),
#  ('released', 14),
#  ('lot', 14),
#  ('end', 14),
#  ('needs', 14),
#  ('rallies', 14),
#  ('without', 14),
#  ('interesting', 14),
#  ('washingtondc', 14),
#  ('terrible', 14),
#  ('melania', 14),
#  ('highly', 14),
#  ('attack', 14),
#  ('message', 14),
#  ('illegalimmigration', 14),
#  ('talking', 14),
#  ('leader', 14),
#  ('hear', 14),
#  ('crowds', 14),
#  ('problem', 14),
#  ('lead', 14),
#  ('increase', 14),
#  ('thousands', 14),
#  ('energy', 14),
#  ('trying', 14),
#  ('times', 14),
#  ('asked', 14),
#  ('donald', 14),
#  ('iwon', 13),
#  ('become', 13),
#  ('russia', 13),
#  ('protect', 13),
#  ('order', 13),
#  ('calls', 13),
#  ('saturday', 13),
#  ('westerngenre', 13),
#  ('future', 13),
#  ('interest', 13),
#  ('hes', 13),
#  ('horrible', 13),
#  ('prayers', 13),
#  ('forget', 13),
#  ('give', 13),
#  ('agree', 13),
#  ('book', 13),
#  ('questions', 13),
#  ('vp', 13),
#  ('lie', 13),
#  ('using', 13),
#  ('border', 13),
#  ('evangelicalism', 13),
#  ('donaldjtrumpjr', 13),
#  ('joenbc', 13),
#  ('nasty', 13),
#  ('paid', 13),
#  ('street', 13),
#  ('borders', 13),
#  ('happened', 13),
#  ('politics', 13),
#  ('convention', 13),
#  ('dead', 13),
#  ('year', 13),
#  ('party', 13),
#  ('unfair', 13),
#  ('wiprimary', 13),
#  ('establishment', 13),
#  ('born', 13),
#  ('leaders', 12),
#  ('corrupt', 12),
#  ('northamericanfreetradeagreement', 12),
#  ('military', 12),
#  ('deals', 12),
#  ('nomination', 12),
#  ('november', 12),
#  ('behind', 12),
#  ('nation', 12),
#  ('mess', 12),
#  ('results', 12),
#  ('honored', 12),
#  ('gets', 12),
#  ('took', 12),
#  ('saw', 12),
#  ('thing', 12),
#  ('seen', 12),
#  ('africanamericans', 12),
#  ('small', 12),
#  ('crazy', 12),
#  ('already', 12),
#  ('anyone', 12),
#  ('desperate', 12),
#  ('meet', 12),
#  ('utah', 12),
#  ('ago', 12),
#  ('reporting', 12),
#  ('word', 12),
#  ('dollars', 12),
#  ('advocacygroup', 12),
#  ('lying', 12),
#  ('zero', 12),
#  ('nationalreview', 12),
#  ('debatenight', 11),
#  ('localexchangetradingsystem', 11),
#  ('transpacificpartnership', 11),
#  ('policies', 11),
#  ('less', 11),
#  ('stand', 11),
#  ('isnt', 11),
#  ('ahead', 11),
#  ('tune', 11),
#  ('appreciate', 11),
#  ('donaldtrumps', 11),
#  ('wintelevision', 11),
#  ('cleveland', 11),
#  ('destroy', 11),
#  ('lawenforcement', 11),
#  ('despite', 11),
#  ('save', 11),
#  ('china', 11),
#  ('else', 11),
#  ('happening', 11),
#  ('pick', 11),
#  ('louisiana', 11),
#  ('build', 11),
#  ('wednesday', 11),
#  ('crime', 11),
#  ('friends', 11),
#  ('familybiology', 11),
#  ('able', 11),
#  ('wowsignal', 11),
#  ('days', 11),
#  ('tell', 11),
#  ('use', 11),
#  ('unitedstatespresidentialelection', 11),
#  ('started', 11),
#  ('republicannationalconvention', 11),
#  ('least', 11),
#  ('wonder', 11),
#  ('top', 11),
#  ('long', 11),
#  ('set', 11),
#  ('st', 11),
#  ('find', 11),
#  ('knew', 11),
#  ('choice', 11),
#  ('republicannationalcommittee', 11),
#  ('johnkasich', 11),
#  ('may', 11),
#  ('happen', 11),
#  ('california', 11),
#  ('care', 11),
#  ('facethenation', 11),
#  ('rickyrubio', 11),
#  ('afternoon', 10),
#  ('raised', 10),
#  ('historyoftheunitedstatesdemocraticparty', 10),
#  ('law', 10),
#  ('instead', 10),
#  ('treated', 10),
#  ('greatly', 10),
#  ('important', 10),
#  ('past', 10),
#  ('taking', 10),
#  ('fighting', 10),
#  ('victims', 10),
#  ('states', 10),
#  ('disgusting', 10),
#  ('guns', 10),
#  ('taken', 10),
#  ('shot', 10),
#  ('missouri', 10),
#  ('funny', 10),
#  ('winner', 10),
#  ('visit', 10),
#  ('packed', 10),
#  ('given', 10),
#  ('illegal', 10),
#  ('loves', 10),
#  ('brexit', 10),
#  ('refuses', 10),
#  ('anymore', 10),
#  ('pushing', 10),
#  ('tv', 10),
#  ('nato', 10),
#  ('bill', 10),
#  ('security', 10),
#  ('playingcardsuit', 10),
#  ('artmovement', 10),
#  ('pocahontas', 10),
#  ('case', 10),
#  ('check', 10),
#  ('reporter', 10),
#  ('piece', 10),
#  ('melaniatrump', 10),
#  ('drop', 10),
#  ('gogame', 10),
#  ('inprimary', 10),
#  ('received', 10),
#  ('glennbeck', 10),
#  ('kansas', 10),
#  ('caucusfortrump', 10),
#  ('liar', 10),
#  ('nbc', 9),
#  ('nights', 9),
#  ('full', 9),
#  ('stage', 9),
#  ('general', 9),
#  ('tax', 9),
#  ('trumptower', 9),
#  ('sevendwarfs', 9),
#  ('perhaps', 9),
#  ('including', 9),
#  ('beautiful', 9),
#  ('someone', 9),
#  ('life', 9),
#  ('arrived', 9),
#  ('friday', 9),
#  ('wouldnt', 9),
#  ('allow', 9),
#  ('lindseygraham', 9),
#  ('wanted', 9),
#  ('waste', 9),
#  ('newsconference', 9),
#  ('poor', 9),
#  ('shes', 9),
#  ('proven', 9),
#  ('gabbybarrett', 9),
#  ('release', 9),
#  ('lose', 9),
#  ('friend', 9),
#  ('short', 9),
#  ('try', 9),
#  ('something', 9),
#  ('pundits', 9),
#  ('vets', 9),
#  ('timeshighereducation', 9),
#  ('everything', 9),
#  ('announced', 9),
#  ('totallybiasedwithwkamaubell', 9),
#  ('democraticnationalcommittee', 9),
#  ('gov', 9),
#  ('group', 9),
#  ('democraticpartyunitedstates', 9),
#  ('speak', 9),
#  ('business', 9),
#  ('husband', 9),
#  ('angry', 9),
#  ('anncoulter', 9),
#  ('vicepresidentoftheunitedstates', 9),
#  ('written', 9),
#  ('presidency', 9),
#  ('eric', 9),
#  ('exciting', 9),
#  ('control', 9),
#  ('bought', 9),
#  ('sent', 9),
#  ('self', 9),
#  ('funding', 9),
#  ('americanbroadcastingcompany', 9),
#  ('correct', 9),
#  ('came', 9),
#  ('fast', 9),
#  ('expected', 9),
#  ('enough', 9),
#  ('kentucky', 9),
#  ('taxreturn', 9),
#  ('fun', 9),
#  ('nyprimary', 9),
#  ('selffunding', 9),
#  ('georgewbush', 9),
#  ('votetrumpsc', 9),
#  ('bobvanderplaats', 9),
#  ('presidential', 8),
#  ('wins', 8),
#  ('discuss', 8),
#  ('barackobamas', 8),
#  ('bclassociateddeathpromoter', 8),
#  ('part', 8),
#  ('pols', 8),
#  ('spoke', 8),
#  ('beginning', 8),
#  ('poorly', 8),
#  ('makes', 8),
#  ('boring', 8),
#  ('former', 8),
#  ('economic', 8),
#  ('club', 8),
#  ('across', 8),
#  ('donaldtrumppresidentialcampaign', 8),
#  ('week', 8),
#  ('free', 8),
#  ('respect', 8),
#  ('respected', 8),
#  ('disgrace', 8),
#  ('reviews', 8),
#  ('post', 8),
#  ('federalbureauofinvestigation', 8),
#  ('ineffective', 8),
#  ('talks', 8),
#  ('outside', 8),
#  ('heard', 8),
#  ('amnesty', 8),
#  ('high', 8),
#  ('rally', 8),
#  ('repeal', 8),
#  ('replace', 8),
#  ('stated', 8),
#  ('tried', 8),
#  ('racism', 8),
#  ('children', 8),
#  ('leading', 8),
#  ('absolutely', 8),
#  ('actually', 8),
#  ('plans', 8),
#  ('pathetic', 8),
#  ('openborder', 8),
#  ('judgment', 8),
#  ('continue', 8),
#  ('chance', 8),
#  ('turned', 8),
#  ('speeches', 8),
#  ('office', 8),
#  ('easily', 8),
#  ('fair', 8),
#  ('norway', 8),
#  ('start', 8),
#  ('air', 8),
#  ('timkaine', 8),
#  ('karlrove', 8),
#  ('hours', 8),
#  ('cbs', 8),
#  ('spatown', 8),
#  ('experience', 8),
#  ('greatnews', 8),
#  ('foreignpolicy', 8),
#  ('favor', 8),
#  ('chucktodd', 8),
#  ('fortune', 8),
#  ('immediately', 8),
#  ('father', 8),
#  ('line', 8),
#  ('losing', 8),
#  ('credibility', 8),
#  ('orlandomagic', 8),
#  ('danscavino', 8),
#  ('finally', 8),
#  ('months', 8),
#  ('todays', 8),
#  ('marco', 8),
#  ('protesters', 8),
#  ('easy', 8),
#  ('oregon', 8),
#  ('megyn', 8),
#  ('everybodymadonnasong', 8),
#  ('tomorrowmorningmusical', 8),
#  ('maryland', 8),
#  ('jervyjervycruz', 8),
#  ('jdickerson', 8),
#  ('highest', 8),
#  ('nydailynews', 8),
#  ('vermont', 8),
#  ('votetrumpnh', 8),
#  ('government', 7),
#  ('sure', 7),
#  ('online', 7),
#  ('final', 7),
#  ('stateadministrationofforeignexchange', 7),
#  ('historic', 7),
#  ('crossmark', 7),
#  ('teamtrump', 7),
#  ('team', 7),
#  ('dem', 7),
#  ('front', 7),
#  ('actionprogramminglanguage', 7),
#  ('followers', 7),
#  ('diamondandsilk', 7),
#  ('hopefully', 7),
#  ('rest', 7),
#  ('georgiausstate', 7),
#  ('attacks', 7),
#  ('met', 7),
#  ('crimeboss', 7),
#  ('gone', 7),
#  ('insanity', 7),
#  ('rights', 7),
#  ('miami', 7),
#  ('hotel', 7),
#  ('hope', 7),
#  ('feel', 7),
#  ('hydrogen', 7),
#  ('second', 7),
#  ('hostile', 7),
#  ('elected', 7),
#  ('fl', 7),
#  ('vladimirputin', 7),
#  ('term', 7),
#  ('longer', 7),
#  ('morningmika', 7),
#  ('georgewashington', 7),
#  ('reuters', 7),
#  ('march', 7),
#  ('vs', 7),
#  ('brought', 7),
#  ('attacked', 7),
#  ('education', 7),
#  ('outfielder', 7),
#  ('play', 7),
#  ('makeamericasafeagain', 7),
#  ('stories', 7),
#  ('rather', 7),
#  ('nd', 7),
#  ('prettylittleliars', 7),
#  ('facts', 7),
#  ('reports', 7),
#  ('rockmusic', 7),
#  ('growth', 7),
#  ('anybody', 7),
#  ('whose', 7),
#  ('incompetent', 7),
#  ('response', 7),
#  ('kind', 7),
#  ('islamicextremism', 7),
#  ('donors', 7),
#  ('third', 7),
#  ('signed', 7),
#  ('statements', 7),
#  ('weeks', 7),
#  ('killing', 7),
#  ('hate', 7),
#  ('speaking', 7),
#  ('embarrassed', 7),
#  ('supported', 7),
#  ('early', 7),
#  ('nominee', 7),
#  ('clue', 7),
#  ('golf', 7),
#  ('lobbying', 7),
#  ('endorse', 7),
#  ('dallas', 7),
#  ('star', 7),
#  ('charges', 7),
#  ('list', 7),
#  ('loan', 7),
#  ('explain', 7),
#  ('possible', 7),
#  ('et', 7),
#  ('dirty', 7),
#  ('playing', 7),
#  ('scotland', 7),
#  ('settled', 7),
#  ('lasvegas', 7),
#  ('based', 7),
#  ('pittsburgh', 7),
#  ('terror', 7),
#  ('newyorkrepublicanstatecommittee', 7),
#  ('thugs', 7),
#  ('nationalorganizationforwomen', 7),
#  ('cover', 7),
#  ('groups', 7),
#  ('loser', 7),
#  ('doubt', 7),
#  ('around', 7),
#  ('head', 7),
#  ('nebraska', 7),
#  ('connecticut', 7),
#  ('realbencarson', 7),
#  ('hawaii', 7),
#  ('mississippi', 7),
#  ('johnnycarson', 7),
#  ('votetrumpnv', 7),
#  ('scprimary', 7),
#  ('eminentdomain', 7),
#  ('nhprimary', 7),
#  ('youre', 6),
#  ('timemagazine', 6),
#  ('except', 6),
#  ('points', 6),
#  ('showing', 6),
#  ('missed', 6),
#  ('sentedcruz', 6),
#  ('knock', 6),
#  ('notice', 6),
#  ('weakness', 6),
#  ('secretary', 6),
#  ('unitedstatessecretservice', 6),
#  ('maybe', 6),
#  ('joining', 6),
#  ('jerryjrfalwell', 6),
#  ('fan', 6),
#  ('landed', 6),
#  ('pass', 6),
#  ('campaigning', 6),
#  ('realdonalddonaldtrump', 6),
#  ('though', 6),
#  ('men', 6),
#  ('irrelevant', 6),
#  ('successful', 6),
#  ('wasnt', 6),
#  ('veteran', 6),
#  ('unfit', 6),
#  ('among', 6),
#  ('late', 6),
#  ('son', 6),
#  ('reported', 6),
#  ('game', 6),
#  ('joe', 6),
#  ('strength', 6),
#  ('turn', 6),
#  ('seeing', 6),
#  ('unable', 6),
#  ('held', 6),
#  ('venue', 6),
#  ('neverhillary', 6),
#  ('loss', 6),
#  ('thoughts', 6),
#  ('neverprofessionalwrestling', 6),
#  ('problems', 6),
#  ('safety', 6),
#  ('company', 6),
#  ('corruption', 6),
#  ('cities', 6),
#  ('ashamed', 6),
#  ('discussing', 6),
#  ('various', 6),
#  ('strongly', 6),
#  ('private', 6),
#  ('ill', 6),
#  ('oh', 6),
#  ('judgejeanine', 6),
#  ('financial', 6),
#  ('etc', 6),
#  ('wild', 6),
#  ('icymi', 6),
#  ('serious', 6),
#  ('ask', 6),
#  ('manufacturing', 6),
#  ('countries', 6),
#  ('owned', 6),
#  ('islamicterrorism', 6),
#  ('supports', 6),
#  ('monday', 6),
#  ('foreign', 6),
#  ('whole', 6),
#  ('thinks', 6),
#  ('facebook', 6),
#  ('stay', 6),
#  ('overrated', 6),
#  ('tomorrownightfilm', 6),
#  ('listenbeyoncsong', 6),
#  ('referred', 6),
#  ('complete', 6),
#  ('minutes', 6),
#  ('heart', 6),
#  ('banks', 6),
#  ('gopconvention', 6),
#  ('ontario', 6),
#  ('americafirstcommittee', 6),
#  ('divided', 6),
#  ('sometimes', 6),
#  ('follow', 6),
#  ('fraudulent', 6),
#  ('endorsing', 6),
#  ('goldmansachs', 6),
#  ('along', 6),
#  ('center', 6),
#  ('lied', 6),
#  ('temperament', 6),
#  ('opponents', 6),
#  ('trouble', 6),
#  ('hell', 6),
#  ('fool', 6),
#  ('meetthepress', 6),
#  ('entire', 6),
#  ('sick', 6),
#  ('nbcnewscom', 6),
#  ('leave', 6),
#  ('values', 6),
#  ('unitedkingdom', 6),
#  ('westvirginia', 6),
#  ('ready', 6),
#  ('open', 6),
#  ('regarding', 6),
#  ('biggest', 6),
#  ('miss', 6),
#  ('usatoday', 6),
#  ('dog', 6),
#  ('newdaycompany', 6),
#  ('forloop', 6),
#  ('credit', 6),
#  ('june', 6),
#  ('badxxxtentacionsong', 6),
#  ('nogunrimassacre', 6),
#  ('wrote', 6),
#  ('conference', 6),
#  ('paper', 6),
#  ('negation', 6),
#  ('hypocrisy', 6),
#  ('constantly', 6),
#  ('lindseygrahamsc', 6),
#  ('bobknight', 6),
#  ('info', 6),
#  ('worth', 6),
#  ('fired', 6),
#  ('brussels', 6),
#  ('neilturner', 6),
#  ('asking', 6),
#  ('illinois', 6),
#  ('commoncorestatestandardsinitiative', 6),
#  ('sc', 6),
#  ('canadiannationalitylaw', 6),
#  ('tricks', 6),
#  ('loans', 6),
#  ('continues', 5),
#  ('theyre', 5),
#  ('touch', 5),
#  ('enjoyed', 5),
#  ('newtgingrich', 5),
#  ('clintonfoundation', 5),
#  ('calling', 5),
#  ('syria', 5),
#  ('iraq', 5),
#  ('simple', 5),
#  ('action', 5),
#  ('taxes', 5),
#  ('policy', 5),
#  ('champion', 5),
#  ('available', 5),
#  ('airplane', 5),
#  ('thinking', 5),
#  ('twice', 5),
#  ('condolences', 5),
#  ('disastermusical', 5),
#  ('secondamendmenttotheunitedstatesconstitution', 5),
#  ('greatest', 5),
#  ('international', 5),
#  ('jimmyfallon', 5),
#  ('transcript', 5),
#  ('lesm', 5),
#  ...]

# %%
get_word_frequencies(clinton_tokens)
# Out:
# [('donaldtrump', 677),
#  ('unitedstates', 320),
#  ('presidentoftheunitedstates', 291),
#  ('hillary', 283),
#  ('people', 190),
#  ('make', 187),
#  ('hillaryclinton', 186),
#  ('one', 175),
#  ('us', 163),
#  ('donaldtrumps', 141),
#  ('families', 132),
#  ('need', 128),
#  ('would', 121),
#  ('women', 119),
#  ('country', 115),
#  ('like', 113),
#  ('let', 110),
#  ('together', 105),
#  ('hydrogen', 105),
#  ('americans', 104),
#  ('get', 102),
#  ('vote', 100),
#  ('every', 95),
#  ('first', 94),
#  ('know', 89),
#  ('donaldtrumponsocialmedia', 89),
#  ('plan', 87),
#  ('going', 86),
#  ('never', 83),
#  ('de', 80),
#  ('time', 80),
#  ('campaign', 80),
#  ('today', 79),
#  ('lets', 79),
#  ('back', 75),
#  ('watch', 73),
#  ('work', 72),
#  ('got', 72),
#  ('live', 71),
#  ('years', 69),
#  ('good', 69),
#  ('take', 69),
#  ('say', 67),
#  ('want', 66),
#  ('right', 64),
#  ('cant', 63),
#  ('help', 62),
#  ('better', 60),
#  ('sure', 60),
#  ('economy', 59),
#  ('day', 59),
#  ('hillarys', 58),
#  ('says', 58),
#  ('new', 58),
#  ('great', 58),
#  ('last', 57),
#  ('many', 57),
#  ('go', 56),
#  ('much', 56),
#  ('believe', 55),
#  ('see', 54),
#  ('everyone', 53),
#  ('millions', 52),
#  ('fight', 52),
#  ('demsinphilly', 52),
#  ('candidate', 51),
#  ('win', 51),
#  ('rncincle', 51),
#  ('proud', 50),
#  ('made', 50),
#  ('hes', 49),
#  ('could', 49),
#  ('working', 49),
#  ('love', 48),
#  ('heres', 48),
#  ('way', 47),
#  ('thank', 47),
#  ('best', 47),
#  ('world', 47),
#  ('kids', 47),
#  ('life', 46),
#  ('said', 46),
#  ('stand', 46),
#  ('man', 46),
#  ('ever', 46),
#  ('timkaine', 45),
#  ('things', 45),
#  ('next', 44),
#  ('million', 44),
#  ('making', 44),
#  ('woman', 43),
#  ('job', 43),
#  ('republicanpartyunitedstates', 43),
#  ('keep', 42),
#  ('still', 42),
#  ('que', 42),
#  ('lgbt', 42),
#  ('debatenight', 41),
#  ('la', 41),
#  ('jobs', 41),
#  ('build', 41),
#  ('deserve', 41),
#  ('wrong', 41),
#  ('election', 40),
#  ('pay', 40),
#  ('tell', 40),
#  ('stop', 40),
#  ('history', 40),
#  ('dont', 40),
#  ('always', 39),
#  ('give', 39),
#  ('youre', 38),
#  ('business', 38),
#  ('thats', 38),
#  ('stronger', 38),
#  ('immigration', 38),
#  ('en', 38),
#  ('everything', 37),
#  ('thing', 37),
#  ('support', 37),
#  ('ago', 37),
#  ('hate', 37),
#  ('think', 36),
#  ('anyone', 36),
#  ('commanderinchief', 36),
#  ('barackobama', 36),
#  ('matter', 35),
#  ('join', 35),
#  ('home', 35),
#  ('even', 35),
#  ('fighting', 35),
#  ('college', 35),
#  ('put', 34),
#  ('night', 34),
#  ('wants', 34),
#  ('real', 33),
#  ('wall', 33),
#  ('hard', 32),
#  ('thetonightshow', 32),
#  ('come', 32),
#  ('well', 32),
#  ('someone', 32),
#  ('year', 32),
#  ('lives', 32),
#  ('ready', 31),
#  ('isnt', 31),
#  ('big', 30),
#  ('really', 30),
#  ('raceandethnicityintheunitedstatescensus', 30),
#  ('words', 29),
#  ('future', 29),
#  ('unitedstatessenate', 29),
#  ('dangerous', 29),
#  ('gunviolence', 29),
#  ('person', 28),
#  ('weve', 28),
#  ('donald', 28),
#  ('look', 28),
#  ('im', 28),
#  ('los', 28),
#  ('lot', 28),
#  ('mikepence', 28),
#  ('gets', 27),
#  ('doesnt', 27),
#  ('thanks', 27),
#  ('tax', 27),
#  ('values', 27),
#  ('nation', 27),
#  ('actually', 27),
#  ('donalddonaldtrump', 27),
#  ('nothing', 26),
#  ('rttvnetwork', 26),
#  ('newyorkcity', 26),
#  ('terrorism', 26),
#  ('rights', 26),
#  ('takes', 25),
#  ('childcare', 25),
#  ('agree', 25),
#  ('part', 25),
#  ('week', 25),
#  ('become', 25),
#  ('long', 25),
#  ('done', 25),
#  ('muslims', 25),
#  ('economic', 25),
#  ('para', 25),
#  ('un', 24),
#  ('team', 24),
#  ('chip', 24),
#  ('needs', 24),
#  ('children', 24),
#  ('share', 24),
#  ('serve', 24),
#  ('enough', 24),
#  ('act', 24),
#  ('debate', 23),
#  ('kind', 23),
#  ('left', 23),
#  ('chance', 23),
#  ('days', 23),
#  ('born', 23),
#  ('must', 23),
#  ('also', 23),
#  ('businesses', 23),
#  ('afford', 23),
#  ('progress', 23),
#  ('familybiology', 23),
#  ('el', 23),
#  ('speech', 23),
#  ('theres', 22),
#  ('important', 22),
#  ('since', 22),
#  ('running', 22),
#  ('makes', 22),
#  ('taxreturn', 22),
#  ('something', 22),
#  ('fix', 22),
#  ('workers', 22),
#  ('nominee', 22),
#  ('fear', 22),
#  ('trail', 22),
#  ('strong', 22),
#  ('foreignpolicy', 22),
#  ('voting', 22),
#  ('nomination', 22),
#  ('imwithher', 21),
#  ('safe', 21),
#  ('money', 21),
#  ('protect', 21),
#  ('knows', 21),
#  ('state', 21),
#  ('demconvention', 21),
#  ('plans', 20),
#  ('another', 20),
#  ('across', 20),
#  ('stage', 20),
#  ('called', 20),
#  ('two', 20),
#  ('text', 20),
#  ('black', 20),
#  ('looks', 20),
#  ('show', 20),
#  ('prejudice', 20),
#  ('qualified', 20),
#  ('run', 20),
#  ('veterans', 20),
#  ('getting', 20),
#  ('violence', 20),
#  ('party', 20),
#  ('zikavirus', 20),
#  ('es', 20),
#  ('leader', 19),
#  ('clear', 19),
#  ('democraticpartyunitedstates', 19),
#  ('raise', 19),
#  ('policies', 19),
#  ('parents', 19),
#  ('young', 19),
#  ('police', 19),
#  ('alone', 19),
#  ('find', 19),
#  ('less', 19),
#  ('able', 19),
#  ('november', 19),
#  ('friends', 19),
#  ('face', 19),
#  ('tune', 19),
#  ('community', 19),
#  ('spent', 19),
#  ('national', 19),
#  ('talks', 19),
#  ('whitehouse', 19),
#  ('vicepresidentoftheunitedstates', 19),
#  ('mother', 19),
#  ('meet', 18),
#  ('middleclass', 18),
#  ('twitter', 18),
#  ('took', 18),
#  ('save', 18),
#  ('students', 18),
#  ('orlandomagic', 18),
#  ('around', 18),
#  ('means', 18),
#  ('unfit', 18),
#  ('mexico', 18),
#  ('heart', 18),
#  ('choice', 18),
#  ('paid', 18),
#  ('security', 18),
#  ('crisis', 18),
#  ('equalpayforequalwork', 18),
#  ('donaldtrumponsocialmedias', 18),
#  ('taxes', 17),
#  ('registered', 17),
#  ('heard', 17),
#  ('idea', 17),
#  ('islamicstateofiraqandthelevant', 17),
#  ('care', 17),
#  ('billclinton', 17),
#  ('seen', 17),
#  ('studentdebt', 17),
#  ('read', 17),
#  ('story', 17),
#  ('elect', 17),
#  ('thinks', 17),
#  ('start', 17),
#  ('place', 17),
#  ('attack', 17),
#  ('saw', 17),
#  ('hear', 16),
#  ('family', 16),
#  ('may', 16),
#  ('problem', 16),
#  ('las', 16),
#  ('talk', 16),
#  ('racism', 16),
#  ('globalwarming', 16),
#  ('follow', 16),
#  ('unitedstatess', 16),
#  ('friend', 16),
#  ('change', 16),
#  ('message', 16),
#  ('men', 16),
#  ('wont', 16),
#  ('judge', 16),
#  ('rhetoric', 16),
#  ('learn', 16),
#  ('access', 16),
#  ('easier', 16),
#  ('portlandtimbersus', 16),
#  ('shes', 15),
#  ('asked', 15),
#  ('celebrate', 15),
#  ('saying', 15),
#  ('living', 15),
#  ('poverty', 15),
#  ('sobre', 15),
#  ('building', 15),
#  ('presidency', 15),
#  ('reality', 15),
#  ('taking', 15),
#  ('end', 15),
#  ('small', 15),
#  ('remember', 15),
#  ('works', 15),
#  ('office', 15),
#  ('respect', 15),
#  ('ideas', 15),
#  ('debt', 15),
#  ('free', 15),
#  ('tough', 15),
#  ('barriers', 15),
#  ('speak', 15),
#  ('affordable', 15),
#  ('ask', 15),
#  ('fair', 15),
#  ('womens', 15),
#  ('lost', 15),
#  ('issues', 15),
#  ('cut', 15),
#  ('unitedstatescongress', 15),
#  ('call', 14),
#  ('else', 14),
#  ('lead', 14),
#  ('su', 14),
#  ('standing', 14),
#  ('without', 14),
#  ('deal', 14),
#  ('top', 14),
#  ('law', 14),
#  ('address', 14),
#  ('release', 14),
#  ('already', 14),
#  ('billion', 14),
#  ('disability', 14),
#  ('talking', 14),
#  ('daughter', 14),
#  ('justice', 14),
#  ('puertorico', 14),
#  ('behind', 14),
#  ('street', 14),
#  ('mom', 14),
#  ('close', 14),
#  ('lose', 14),
#  ('trying', 14),
#  ('guy', 14),
#  ('lgbtrightsbycountryorterritory', 14),
#  ('create', 14),
#  ('military', 14),
#  ('deportation', 14),
#  ('happen', 14),
#  ('anything', 14),
#  ('listenbeyoncsong', 14),
#  ('primary', 14),
#  ('action', 13),
#  ('couldnt', 13),
#  ('away', 13),
#  ('homes', 13),
#  ('register', 13),
#  ('arent', 13),
#  ('nuclearweapon', 13),
#  ('hands', 13),
#  ('bring', 13),
#  ('imaginesoftware', 13),
#  ('theyre', 13),
#  ('courage', 13),
#  ('far', 13),
#  ('historyoftheunitedstatesrepublicanparty', 13),
#  ('exactly', 13),
#  ('none', 13),
#  ('break', 13),
#  ('leave', 13),
#  ('defeat', 13),
#  ('voters', 13),
#  ('major', 13),
#  ('whether', 13),
#  ('war', 13),
#  ('health', 13),
#  ('supporting', 13),
#  ('allies', 13),
#  ('hurt', 13),
#  ('company', 13),
#  ('possible', 13),
#  ('nbcnewsforum', 13),
#  ('leadership', 13),
#  ('companies', 13),
#  ('head', 13),
#  ('casinos', 13),
#  ('congrats', 13),
#  ('millionaires', 13),
#  ('berniesanders', 13),
#  ('del', 13),
#  ('prepared', 12),
#  ('biggest', 12),
#  ('whos', 12),
#  ('thetonightshows', 12),
#  ('told', 12),
#  ('watching', 12),
#  ('youve', 12),
#  ('benefits', 12),
#  ('ways', 12),
#  ('entire', 12),
#  ('trust', 12),
#  ('grow', 12),
#  ('yet', 12),
#  ('shouldnt', 12),
#  ('others', 12),
#  ('honor', 12),
#  ('used', 12),
#  ('calls', 12),
#  ('harder', 12),
#  ('threat', 12),
#  ('forward', 12),
#  ('try', 12),
#  ('hold', 12),
#  ('hillaryclintons', 12),
#  ('todays', 12),
#  ('faith', 12),
#  ('suffrage', 12),
#  ('healthcare', 12),
#  ('st', 12),
#  ('playing', 12),
#  ('bankruptcy', 12),
#  ('womancard', 12),
#  ('paying', 11),
#  ('answer', 11),
#  ('check', 11),
#  ('built', 11),
#  ('problems', 11),
#  ('gunpoliticsintheunitedstates', 11),
#  ('pretty', 11),
#  ('add', 11),
#  ('decisions', 11),
#  ('bullying', 11),
#  ('elevator', 11),
#  ('color', 11),
#  ('africanamericans', 11),
#  ('ovaloffice', 11),
#  ('voice', 11),
#  ('democracy', 11),
#  ('progressive', 11),
#  ('virginia', 11),
#  ('political', 11),
#  ('divisive', 11),
#  ('news', 11),
#  ('looking', 11),
#  ('pick', 11),
#  ('billionaires', 11),
#  ('potential', 11),
#  ('trumpuniversity', 11),
#  ('victims', 11),
#  ('speaking', 11),
#  ('son', 11),
#  ('protecting', 11),
#  ('hateful', 11),
#  ('happy', 11),
#  ('everybody', 11),
#  ('whole', 11),
#  ('education', 11),
#  ('runningmate', 11),
#  ('gun', 11),
#  ('checkmark', 11),
#  ('singlemusic', 10),
#  ('turn', 10),
#  ('set', 10),
#  ('northcarolina', 10),
#  ('word', 10),
#  ('moment', 10),
#  ('fact', 10),
#  ('hed', 10),
#  ('discrimination', 10),
#  ('profits', 10),
#  ('fired', 10),
#  ('questions', 10),
#  ('serviceflag', 10),
#  ('service', 10),
#  ('started', 10),
#  ('released', 10),
#  ('divides', 10),
#  ('line', 10),
#  ('child', 10),
#  ('equal', 10),
#  ('trumpcardgames', 10),
#  ('school', 10),
#  ('minimumwage', 10),
#  ('greatest', 10),
#  ('insults', 10),
#  ('challenges', 10),
#  ('believes', 10),
#  ('indiana', 10),
#  ('accept', 10),
#  ('higher', 10),
#  ('rich', 10),
#  ('ohio', 10),
#  ('foreign', 10),
#  ('personal', 10),
#  ('decision', 10),
#  ('prevent', 10),
#  ('wages', 10),
#  ('deserves', 10),
#  ('convention', 10),
#  ('instead', 10),
#  ('toward', 10),
#  ('folks', 10),
#  ('joebiden', 10),
#  ('hectare', 10),
#  ('newyorkrepublicanstatecommittee', 10),
#  ('breaks', 10),
#  ('pennsylvania', 10),
#  ('might', 10),
#  ('tributyltin', 10),
#  ('wage', 10),
#  ('smart', 9),
#  ('candidates', 9),
#  ('gogame', 9),
#  ('goes', 9),
#  ('least', 9),
#  ('ive', 9),
#  ('name', 9),
#  ('charge', 9),
#  ('low', 9),
#  ('barackobamacitizenshipconspiracytheories', 9),
#  ('institutionalracism', 9),
#  ('trillion', 9),
#  ('smallbusiness', 9),
#  ('held', 9),
#  ('situationroom', 9),
#  ('endorses', 9),
#  ('sees', 9),
#  ('speaks', 9),
#  ('old', 9),
#  ('ties', 9),
#  ('power', 9),
#  ('feel', 9),
#  ('bad', 9),
#  ('helped', 9),
#  ('society', 9),
#  ('public', 9),
#  ('communities', 9),
#  ('killed', 9),
#  ('officers', 9),
#  ('ahead', 9),
#  ('sign', 9),
#  ('prisoners', 9),
#  ('facing', 9),
#  ('whitesupremacy', 9),
#  ('bridges', 9),
#  ('grateful', 9),
#  ('firstladyoftheunitedstates', 9),
#  ('career', 9),
#  ('polls', 9),
#  ('dream', 9),
#  ('stands', 9),
#  ('risk', 9),
#  ('known', 9),
#  ('leaders', 9),
#  ('california', 9),
#  ('literally', 9),
#  ('books', 9),
#  ('little', 9),
#  ('different', 9),
#  ('kindness', 9),
#  ('became', 9),
#  ('schools', 9),
#  ('mentalhealth', 9),
#  ('se', 9),
#  ('vladimirputin', 9),
#  ('former', 9),
#  ('combat', 9),
#  ('helping', 9),
#  ('apart', 9),
#  ('funding', 9),
#  ('along', 9),
#  ('biden', 9),
#  ('reckless', 9),
#  ('taxcut', 9),
#  ('policy', 9),
#  ('move', 9),
#  ('employees', 9),
#  ('represent', 9),
#  ('ground', 9),
#  ('todos', 9),
#  ('count', 9),
#  ('abortion', 9),
#  ('profit', 9),
#  ('nobillnobreak', 9),
#  ('vision', 8),
#  ('injustice', 8),
#  ('dad', 8),
#  ('electionday', 8),
#  ('con', 8),
#  ('hours', 8),
#  ('deeply', 8),
#  ('true', 8),
#  ('russia', 8),
#  ('unitedstatespresidentialelection', 8),
#  ('giving', 8),
#  ('refusing', 8),
#  ('lie', 8),
#  ('presidential', 8),
#  ('housing', 8),
#  ('countries', 8),
#  ('four', 8),
#  ('accountable', 8),
#  ('lying', 8),
#  ('solve', 8),
#  ('three', 8),
#  ('experience', 8),
#  ('inclusive', 8),
#  ('past', 8),
#  ('record', 8),
#  ('endorsing', 8),
#  ('flint', 8),
#  ('breaking', 8),
#  ('struggling', 8),
#  ('hope', 8),
#  ('expand', 8),
#  ('succeed', 8),
#  ('especially', 8),
#  ('champion', 8),
#  ('defend', 8),
#  ('thinking', 8),
#  ('hearts', 8),
#  ('walls', 8),
#  ('finally', 8),
#  ('attacks', 8),
#  ('clintonfdn', 8),
#  ('worldwarii', 8),
#  ('becoming', 8),
#  ('terrible', 8),
#  ('tuition', 8),
#  ('opportunity', 8),
#  ('comes', 8),
#  ('leading', 8),
#  ('agenda', 8),
#  ('msalbum', 8),
#  ('parentalleave', 8),
#  ('comments', 8),
#  ('th', 8),
#  ('interests', 8),
#  ('serious', 8),
#  ('latest', 8),
#  ('fraud', 8),
#  ('yes', 8),
#  ('cost', 8),
#  ('fund', 8),
#  ('members', 8),
#  ('strength', 8),
#  ('letter', 8),
#  ('facebook', 8),
#  ('connecticut', 8),
#  ('side', 8),
#  ('success', 8),
#  ('goodpaying', 8),
#  ('tomorrow', 8),
#  ('familias', 8),
#  ('backhandindexpointingleft', 8),
#  ('unadistrict', 8),
#  ('fighteraircraft', 8),
#  ('nationalvoterregistrationday', 7),
#  ('proposal', 7),
#  ('times', 7),
#  ('months', 7),
#  ('strongertogether', 7),
#  ('opponent', 7),
#  ('losing', 7),
#  ('income', 7),
#  ('miss', 7),
#  ('proved', 7),
#  ('didnt', 7),
#  ('anywhere', 7),
#  ('iraq', 7),
#  ('high', 7),
#  ('loved', 7),
#  ('somebody', 7),
#  ('hiding', 7),
#  ('step', 7),
#  ('owner', 7),
#  ('pm', 7),
#  ('lies', 7),
#  ('facts', 7),
#  ('endorsed', 7),
#  ('lifetime', 7),
#  ('girl', 7),
#  ('backs', 7),
#  ('legal', 7),
#  ('almost', 7),
#  ('test', 7),
#  ('treat', 7),
#  ('historyoftheunitedstatesdemocraticparty', 7),
#  ('reform', 7),
#  ('shot', 7),
#  ('ballot', 7),
#  ('powerful', 7),
#  ('tear', 7),
#  ('path', 7),
#  ('matters', 7),
#  ('commit', 7),
#  ('youll', 7),
#  ('climate', 7),
#  ('ktsu', 7),
#  ('seriously', 7),
#  ('conspiracytheory', 7),
#  ('reject', 7),
#  ('afraid', 7),
#  ('americandream', 7),
#  ('diversity', 7),
#  ('theyve', 7),
#  ('willing', 7),
#  ('glassceiling', 7),
#  ('sacrificeinmayaculture', 7),
#  ('march', 7),
#  ('solutions', 7),
#  ('kukluxklan', 7),
#  ('buy', 7),
#  ('economyoftheunitedstates', 7),
#  ('elizabethforma', 7),
#  ('philadelphia', 7),
#  ('secret', 7),
#  ('unlike', 7),
#  ('understands', 7),
#  ('leads', 7),
#  ('episode', 7),
#  ('generals', 7),
#  ('bill', 7),
#  ('unitedstateshouseofrepresentatives', 7),
#  ('totally', 7),
#  ('tried', 7),
#  ('unqualifiedpodcast', 7),
#  ('proven', 7),
#  ('tiene', 7),
#  ('brought', 7),
#  ('unions', 7),
#  ('humanrights', 7),
#  ('process', 7),
#  ('came', 7),
#  ('fought', 7),
#  ('struggle', 7),
#  ('honored', 7),
#  ('supporters', 7),
#  ('taken', 7),
#  ('temperamentally', 7),
#  ('thousands', 7),
#  ('coming', 7),
#  ('highfunctioningautism', 7),
#  ('voices', 7),
#  ('loophole', 7),
#  ('hardworking', 7),
#  ('states', 7),
#  ('century', 7),
#  ('investment', 7),
#  ('listening', 7),
#  ('happening', 7),
#  ('city', 7),
#  ('platform', 7),
#  ('pence', 7),
#  ('plannedparenthood', 7),
#  ('scotus', 7),
#  ('ones', 7),
#  ('tucuneiform', 7),
#  ('estoyconella', 7),
#  ('kentucky', 7),
#  ('maryland', 7),
#  ('sit', 6),
#  ('lovetrumpshate', 6),
#  ('rallying', 6),
#  ('winning', 6),
#  ('feeling', 6),
#  ('spread', 6),
#  ('global', 6),
#  ('near', 6),
#  ('supported', 6),
#  ('sued', 6),
#  ('led', 6),
#  ('five', 6),
#  ('concerned', 6),
#  ('nationaldebtoftheunitedstates', 6),
#  ('products', 6),
#  ('list', 6),
#  ('et', 6),
#  ('epidemic', 6),
#  ('daughters', 6),
#  ('brave', 6),
#  ('changing', 6),
#  ('course', 6),
#  ('recommit', 6),
#  ('death', 6),
#  ('board', 6),
#  ('via', 6),
#  ('thought', 6),
#  ('commitment', 6),
#  ('becomes', 6),
#  ('committed', 6),
#  ('nearly', 6),
#  ('nobody', 6),
#  ('hasnt', 6),
#  ('podcast', 6),
#  ('often', 6),
#  ('promise', 6),
#  ('dreams', 6),
#  ('charitableorganization', 6),
#  ('walk', 6),
#  ('university', 6),
#  ('tuitionfree', 6),
#  ('simple', 6),
#  ('laws', 6),
#  ('hatred', 6),
#  ('debtfree', 6),
#  ('generation', 6),
#  ('choose', 6),
#  ('thoughts', 6),
#  ('wrote', 6),
#  ('taught', 6),
#  ('elected', 6),
#  ('happybirthdaytoyou', 6),
#  ('seem', 6),
#  ('septemberattacks', 6),
#  ('newjersey', 6),
#  ('white', 6),
#  ('fall', 6),
#  ('understand', 6),
#  ('houseofeste', 6),
#  ('preventing', 6),
#  ('actions', 6),
#  ('citizenship', 6),
#  ('refused', 6),
#  ('shape', 6),
#  ('hacer', 6),
#  ('comprehensiveimmigrationreformactof', 6),
#  ('passion', 6),
#  ('joinsql', 6),
#  ('stay', 6),
#  ('pass', 6),
#  ('dignity', 6),
#  ('joe', 6),
#  ('citizens', 6),
#  ('donalddonaldtrumps', 6),
#  ('soon', 6),
#  ('room', 6),
#  ('highest', 6),
#  ('openly', 6),
#  ('picture', 6),
#  ('quality', 6),
#  ('politics', 6),
#  ('perfect', 6),
#  ('lo', 6),
#  ('nuestro', 6),
#  ('involved', 6),
#  ('imagine', 6),
#  ('force', 6),
#  ('reasons', 6),
#  ('secretary', 6),
#  ('use', 6),
#  ('enter', 6),
#  ('hitsong', 6),
#  ('gave', 6),
#  ('price', 6),
#  ('special', 6),
#  ('deliver', 6),
#  ('texas', 6),
#  ('hit', 6),
#  ('extreme', 6),
#  ('dictators', 6),
#  ('goal', 6),
#  ('devastating', 6),
#  ('huge', 6),
#  ('victory', 6),
#  ('welcome', 6),
#  ('entering', 6),
#  ('tedcruz', 6),
#  ('whats', 6),
#  ('official', 6),
#  ('teamusa', 6),
#  ('thisweekamericantvprogram', 6),
#  ('spend', 6),
#  ('unites', 6),
#  ('card', 6),
#  ('historic', 6),
#  ('cleveland', 6),
#  ('barrier', 6),
#  ('written', 6),
#  ('hiring', 6),
#  ('doubt', 6),
#  ('corporations', 6),
#  ('full', 6),
#  ('incredible', 6),
#  ('earn', 6),
#  ('requires', 6),
#  ('majority', 6),
#  ('wish', 6),
#  ('account', 6),
#  ('abrahamlincoln', 6),
#  ('tim', 6),
#  ('common', 6),
#  ('guns', 6),
#  ('al', 6),
#  ('demagogue', 6),
#  ('fights', 6),
#  ('savings', 6),
#  ('voted', 6),
#  ('offer', 6),
#  ('wait', 6),
#  ('raising', 6),
#  ('prayers', 6),
#  ('teachers', 6),
#  ('votar', 6),
#  ('rhodeisland', 6),
#  ('yorkers', 6),
#  ('question', 5),
#  ('nights', 5),
#  ('showed', 5),
#  ('racial', 5),
#  ('reduce', 5),
#  ('lied', 5),
#  ('brings', 5),
#  ('please', 5),
#  ('criticized', 5),
#  ('temperament', 5),
#  ('seeking', 5),
#  ('turning', 5),
#  ('meeting', 5),
#  ('pushing', 5),
#  ('reason', 5),
#  ('criminaljustice', 5),
#  ('program', 5),
#  ('planet', 5),
#  ('invest', 5),
#  ('sustainableenergy', 5),
#  ('crash', 5),
#  ('thebriefing', 5),
#  ('example', 5),
#  ('mind', 5),
#  ('thenewyorktimes', 5),
#  ('endorsement', 5),
#  ('open', 5),
#  ('failing', 5),
#  ('favorite', 5),
#  ('moments', 5),
#  ('refuses', 5),
#  ('mittromney', 5),
#  ('created', 5),
#  ('respectmagazine', 5),
#  ('basic', 5),
#  ('helps', 5),
#  ('student', 5),
#  ('king', 5),
#  ('ad', 5),
#  ('sticker', 5),
#  ('given', 5),
#  ('trusted', 5),
#  ('shows', 5),
#  ('drive', 5),
#  ('loose', 5),
#  ('optimism', 5),
#  ('destroy', 5),
#  ('presidentoftheunitedstatess', 5),
#  ('beat', 5),
#  ('went', 5),
#  ('served', 5),
#  ('votes', 5),
#  ...]

# %%
i = 0
k = 0
for s in trump_tokens:
  for word in s:
    if word == 'hillary':
      print(i)
      k = k +1
  i = i + 1
# Out:
# 17
# 59
# 88
# 90
# 93
# 112
# 117
# 172
# 191
# 197
# 216
# 231
# 232
# 235
# 242
# 281
# 283
# 284
# 290
# 290
# 302
# 303
# 311
# 313
# 317
# 361
# 363
# 409
# 410
# 412
# 414
# 427
# 482
# 484
# 486
# 531
# 533
# 534
# 538
# 539
# 552
# 555
# 556
# 562
# 564
# 566
# 572
# 573
# 577
# 585
# 586
# 587
# 591
# 595
# 600
# 605
# 619
# 635
# 639
# 640
# 649
# 656
# 657
# 668
# 669
# 671
# 672
# 675
# 678
# 680
# 682
# 683
# 700
# 704
# 706
# 764
# 766
# 767
# 768
# 775
# 776
# 777
# 778
# 782
# 782
# 787
# 810
# 811
# 814
# 827
# 835
# 835
# 842
# 843
# 844
# 849
# 851
# 852
# 853
# 854
# 859
# 862
# 864
# 865
# 866
# 873
# 881
# 882
# 884
# 891
# 906
# 912
# 913
# 915
# 919
# 933
# 941
# 942
# 945
# 948
# 949
# 951
# 952
# 954
# 956
# 966
# 972
# 991
# 993
# 1002
# 1004
# 1006
# 1008
# 1012
# 1014
# 1015
# 1016
# 1038
# 1061
# 1065
# 1076
# 1076
# 1078
# 1099
# 1100
# 1113
# 1114
# 1117
# 1120
# 1143
# 1144
# 1151
# 1152
# 1164
# 1193
# 1194
# 1195
# 1195
# 1198
# 1202
# 1203
# 1208
# 1212
# 1223
# 1243
# 1262
# 1266
# 1266
# 1280
# 1284
# 1285
# 1292
# 1293
# 1297
# 1299
# 1300
# 1301
# 1304
# 1307
# 1310
# 1311
# 1311
# 1313
# 1314
# 1323
# 1326
# 1326
# 1327
# 1328
# 1329
# 1330
# 1339
# 1342
# 1346
# 1349
# 1350
# 1382
# 1383
# 1386
# 1387
# 1389
# 1390
# 1392
# 1394
# 1429
# 1440
# 1447
# 1448
# 1453
# 1454
# 1461
# 1461
# 1462
# 1472
# 1485
# 1487
# 1496
# 1500
# 1506
# 1509
# 1514
# 1516
# 1526
# 1527
# 1547
# 1551
# 1556
# 1570
# 1636
# 1662
# 1687
# 1688
# 1692
# 1693
# 1695
# 1868
# 1937
# 1945
# 2008
# 2065
# 2065
# 2080
# 2102
# 2108
# 2240
# 2293
# 2315
# 2359
# 2408
# 2526
# 2535
# 2545
# 2563
# 2791
# 2791
# 2927
# 2981
# 3002
# 3010
# 3017
# 3181
# 3201

# %%
k
# Out:
# 262

# %%
trump_cleaned[2293]
# Out:
# 'Hillary could lose to DonaldTrump in DemocraticPartyUnitedStates NewYorkCity\nMakeAmericaGreatAgain DonaldTrump\n'

# %%
trump_tokens[2293]
# Out:
# ['hillary',
#  'could',
#  'lose',
#  'donaldtrump',
#  'democraticpartyunitedstates',
#  'newyorkcity',
#  'makeamericagreatagain',
#  'donaldtrump']

# %% [markdown]
# #Polarity

# %%
def polarity(model, topic, positive, negative):
  positive_score = 0
  negative_score = 0

  for t in topic:

    positive_temp = 0
    for p in positive:
      positive_temp = positive_temp + ( 1 - cosine(model[t], model[p]))
    positive_temp = positive_temp/len(positive)
    

    negative_temp = 0
    for n in negative:
      negative_temp = negative_temp + (1 - cosine(model[t], model[n]))
    negative_temp = negative_temp/len(negative)

    positive_score = positive_score + positive_temp
    negative_score = negative_score + negative_temp

  print('Positive score: ', positive_score)
  print('Negative score: ', negative_score)
  print('Difference score: ', positive_score - negative_score)

# %% [markdown]
# # Trump

# %%
trump_model = Word2Vec(trump_tokens, sg=0, seed = 1, sample=0, window=5, min_count= 2 )
#vocabulary = list(trump_model.wv.vocab)

print(trump_model)
# Out:
# Word2Vec(vocab=2701, size=100, alpha=0.025)

# %%
summing = trump_model["hillaryclinton"] + trump_model["hillary"] 
trump_model.most_similar(positive=[summing])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('hillary', 0.9996767640113831),
#  ('hillaryclinton', 0.9993463754653931),
#  ('beat', 0.9984186887741089),
#  ('berniesanders', 0.9982447624206543),
#  ('cant', 0.9980177879333496),
#  ('barackobama', 0.9979698061943054),
#  ('believe', 0.9978654980659485),
#  ('lyin', 0.9977784156799316),
#  ('wants', 0.9977516531944275),
#  ('says', 0.9977107048034668)]

# %%
topic = [ 'barackobama']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong']

polarity(trump_model, topic, positive, negative)
# Out:
# Positive score:  0.9960370540618897
# Negative score:  0.9994620680809021
# Difference score:  -0.0034250140190124068
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app

# %%
topic = [ 'hillary', 'clinton', 'dem', 'hillaryclinton']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong']

polarity(trump_model, topic, positive, negative)
# Out:
# Positive score:  3.9646677136421205
# Negative score:  3.9796245455741883
# Difference score:  -0.014956831932067871
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app

# %%
1 - cosine(trump_model['hillary'], trump_model['bad'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# 0.9954649806022644

# %%
1 - cosine(trump_model['trump'], trump_model['bad'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# 0.9745658040046692

# %% [markdown]
# # Clinton

# %%
clinton_model = Word2Vec(clinton_tokens, sg=0, seed = 1, sample=0, window=5, min_count= 2 )
#vocabulary = list(trump_model.wv.vocab)

print(clinton_model)
# Out:
# Word2Vec(vocab=2766, size=100, alpha=0.025)

# %%
summing = clinton_model["great"]
clinton_model.most_similar(positive=[summing])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('great', 0.9999999403953552),
#  ('unitedstates', 0.9997862577438354),
#  ('people', 0.9997547268867493),
#  ('make', 0.9997491240501404),
#  ('one', 0.9997435808181763),
#  ('presidentoftheunitedstates', 0.9997369647026062),
#  ('women', 0.9997368454933167),
#  ('us', 0.9997341632843018),
#  ('like', 0.9997197389602661),
#  ('never', 0.9997180700302124)]

# %%
topic = [ 'donaldtrump', 'donald', 'republican']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong', 'war']

polarity(clinton_model, topic, positive, negative)
# Out:
# Positive score:  2.7165546298027037
# Negative score:  2.85475688179334
# Difference score:  -0.13820225199063652
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app

# %%
topic = [ 'barackobama']
positive = ['good', 'great', 'nice', 'positive', 'love' ]
negative = ['bad', 'badly', 'negative', 'false', 'wrong', 'war']

polarity(clinton_model, topic, positive, negative)
# Out:
# Positive score:  0.927637767791748
# Negative score:  0.9712708592414856
# Difference score:  -0.04363309144973759
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app

# %% [markdown]
# # Save model

# %%
trump_model.save('trump_w2v.model')
clinton_model.save('clinton_w2v.model')
